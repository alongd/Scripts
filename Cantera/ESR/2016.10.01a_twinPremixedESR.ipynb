# %% [markdown]
# ## Extinction Strain Rate with Sensitivity Alalysis
#
# Run with Cantera version 2.3.0 or higher.<BR>
# Written by Alon Grinberg Dana, inspired by:<BR>
# (1) <a href="https://github.com/Cantera/cantera-jupyter/blob/master/flames/twin_premixed_flame_axisymmetric.ipynb">twin_premixed_flame_axisymmetric.ipynb</a> in Cantera, and<BR>
# (2) <a href="http://www.cantera.org/docs/sphinx/html/cython/examples/onedim_diffusion_flame_extinction.html"> diffusion_flame_extinction.py</a> (cite: <a href="http://dx.doi.org/10.1155/2014/484372">doi:10.1155/2014/484372</a>)
#
# **See comments and instructions at the bottom of this notebook**

# %% [markdown]
# ## Import modules

# %%
from mpl_toolkits.mplot3d import Axes3D
from __future__ import print_function
from __future__ import division
import matplotlib.pyplot as plt
from shutil import copyfile
from sys import stdout
import cantera as ct
import pandas as pd
import numpy as np
import operator
import pylab
import time
import os
# delete if working outside Jupyter:
# %matplotlib notebook

print("Running Cantera Version: " + str(ct.__version__))
# Out:
# Running Cantera Version: 2.3.0a3

# %% [markdown]
# ## User variables

# %%
initialAxialVelocity = 200                     # cm/s; Set the initial inlet axial velocity

model = 'mechs/xo1247R.cti'                    # relative path to the mechanism input file (.cti form)
composition = 'CH4(1):0.4615, O2(2):1, N2(3):3.76'

name = "SA"                             # name will be used for the output files

To = 300                # K, default:  300
Po = ct.one_atm * 1     # atm
#Po = 101325            # Pa, default: 101325

half_width = 0.7        # Define a domain half-width x cm wide (i.e., the whole domain is 2x cm wide)

topSA = 10     # default: 10 (choose the top sensitive reactions to display, enter 0 to skip SA altogether)
#topSA = 10   # default: 10 (choose the top sensitive reactions to display, enter 0 to skip SA altogether)
dk = 1.05     # default: 1.02 pertubation multiplier for Ai

# number of grid points; set to 0 to be determined automatically by the solver
#(auto is recommended at first since it's fast, but not as accurate as having a large grid)
grid_pnts = 0  # default: 0 for auto, 1000 for uniform
refine = True  # defauld: True (recommended) ; enable grid refinement?

verboseLevel = 3 # default: 3 (1 essentials, 2 all, 3 also figs; one lvl up for SA; in any case all is saved to files)

species1 = ''    # plot concentration profiles. Leave blank ('') to repress plotting
species2 = ''

tran = 'Multi' # default: 'Multi'; choose transport calculation method: 'Mix' for mixture-averaged or 'Multi' for multi-component

# Define a limit for the maximum temperature below which the flame is considered as extinguished
temperature_limit_extinction = 1000  # K, default: 1000
# convergence creterion for the change in max T
delta_T_min = 0.5  # K, default: 0.5

# Troubleshooting parameters
delta_alpha_low_boundary = 1e-15 # default: 1e-15 (If a solution cannot be obtained by reducing delta alpha)
max_n = 200 # default: 200 (max 'normal' iterations before speeding things up)
# The axial velocity will be multiplied by AxialVelocityIncreaseFactor * (vIncCount + delta_v_factor)
# if extinction takes too long to achieve (determined by n_max)
# Or divided by AxialVelocityDecreaseFactor * (vDecCount + delta_v_factor)
# if ignition can't be achieved.
# note: AxialVelocityDecreaseFactor and AxialVelocityIncreaseFactor should be different to avoid going back and forth
axialVelocityIncreaseFactor = 2.5 # default: 2.5
axialVelocityDecreaseFactor = 2 # default: 2
u_vIncCount = 1 # initialAxialVelocity aux increase factor
u_vDecCount = 1 # initialAxialVelocity aux decrease factor
delta_v_factor = 0.2 # default: 0.2 (increment of vIncCount and vDecCount every time the axial velocity needs a boost)

# Set normalized initial strain rate
u_alpha = [1.]                # default: [1.] (has to be a list)
# Initial relative strain rate increase
u_delta_alpha = 1.            # default: 1.
# Factor of refinement of the strain rate increase
delta_alpha_factor = 50.      # default: 50.
# convergence creterion for delta_alpha
delta_alpha_min = 1E-3        # default: 1E-3; recommended values: 1E-1, 1E-3, 1E-5, 1E-6

# set tolerances
steady_tolerances = [1.0e-5, 1.0e-12]    # relative and absolute, default: [1.0e-5, 1.0e-12]
transient_tolerances = [1.0e-4, 1.0e-9]  # relative and absolute, default: [5.0e-4, 1.0e-11]

# SET CRITERIA FOR GRID REFINEMENT
ratio = 2.0   # default: 2.0  (10.0 in Cantera)
slope = 0.25  # default: 0.3  (0.8 in Cantera), (0.0 < slope < 1.0)
curve = 0.25  # default: 0.3  (0.8 in Cantera), (0.0 < curve < 1.0)
prune = 0.03  # default: 0.05 (0.0 in Cantera) Set << 'slope' or 'curve'; zero to disable pruning the grid

# Exponents for the initial solution variation with changes in strain rate
# Taken from Fiala and Sattelmayer (2014)
exp_d_a = - 1. / 2.   # default: - 1. / 2.
exp_u_a = 1. / 2.     # default: 1. / 2.
exp_V_a = 1.          # default: 1.
exp_lam_a = 2.        # default: 2.
exp_mdot_a = 1. / 2.  # default: 1. / 2.

# data directory; If you run this script in parallel from the same directory,
# it is recommended to give a different data directory name to each instance
u_data_directory = 'ESR_data/' # default: 'ESR_data/'

# %% [markdown]
# ## Functions and definitions

# %%
def initializer(v):
    alpha = u_alpha
    delta_alpha = u_delta_alpha
    gas = ct.Solution(model)
    gas.TPX = To, Po, composition
    width = half_width * 0.01
    # Create the flame object
    if grid_pnts == 0:
        oppFlame = ct.CounterflowTwinPremixedFlame(gas, width=width)
    else:
        grid = np.linspace(0.0, width, grid_pnts)
        oppFlame = ct.CounterflowTwinPremixedFlame(gas, grid=grid)
    oppFlame.reactants.mdot = gas.density * v * 0.01 # units kg/m2/s
    oppFlame.transport_model = tran
    # Define relative and absolute error tolerances
    oppFlame.flame.set_steady_tolerances(default=steady_tolerances)
    oppFlame.flame.set_transient_tolerances(default=transient_tolerances)
    oppFlame.set_refine_criteria(ratio=ratio, slope=slope, curve=curve, prune=prune)
    return gas, oppFlame, alpha, delta_alpha, width

# Differentiation function; used to compute normal strain-rate
def derivative(x, y):
    dydx = np.zeros(y.shape, y.dtype.type)
    dx = np.diff(x)
    dy = np.diff(y)
    dydx[0:-1] = dy/dx
    dydx[-1] = (y[-1] - y[-2])/(x[-1] - x[-2])
    return dydx

def computeStrainRates(oppFlame):
    # Compute the derivative of axial velocity to obtain normal strain rate
    strainRates = derivative(oppFlame.grid, oppFlame.u)
    # Obtain the Characteristic Strain Rate (K)
    n = 0
    while strainRates[n] > strainRates[n+1]:
        n +=1
    strainRatePoint = n
    K = abs(strainRates[n])
    return strainRates, strainRatePoint, K

def computeConsumptionSpeed(oppFlame):
    Tb = max(oppFlame.T)
    Tu = min(oppFlame.T)
    rho_u = max(oppFlame.density)
    integrand = oppFlame.heat_release_rate/oppFlame.cp
    I = np.trapz(integrand, oppFlame.grid)
    Sc = I/(Tb - Tu)/rho_u
    return Sc

def column(matrix, i):
    return [row[i] for row in matrix]

def solver(gas, oppFlame, alpha, delta_alpha, width, t0):
    n = -1                         # Iteration indicator
    tracker = []                   # Tracking: n, u0, ESR, Tmax
    t = -1                         # tracker index
    n_last_burning = 0             # Indicator of the latest flame still burning
    T_max = [np.max(oppFlame.T)]   # List of peak temperatures
    axialVelocity = [initialAxialVelocity]
    S1 = []
    S2 = []
    restoreSwitch = 0              # indicate the number of times troubleshooting was attempted
    SArestoreFile = 1              # save restore file at the first time delta_alpha is reduced for SA continuation
    vIncCount = u_vIncCount
    vDecCount = u_vDecCount
    log = []                       # log troubleshooting messages for output file
    print("Solving %s with u0 = %6.1f cm/s:"%(stripModelName(model),100*oppFlame.reactants.mdot/gas.density))
    while True:
        strainRates, strainRatePoint, K = computeStrainRates(oppFlame)
        n += 1
        # try solving
        try:
            oppFlame.solve(loglevel=0, refine_grid=refine, auto=True)
        except Exception as e:
            if verboseLevel >= 2:
                print("\nError: Did not converge at n = %3d. alpha = %8.2e,   delta_alppha = %8.2e,   Tmax = %8.1f K"%(
                        n, alpha[-1], delta_alpha, np.max(oppFlame.T)))
        # if still burning: save, append, check for convergence
        if np.max(oppFlame.T) > temperature_limit_extinction:
            n_last_burning = n
            t += 1
            tracker.append([n, np.max(oppFlame.u)*100, K, np.max(oppFlame.T)])
            if verboseLevel >=1:
                t1 = time.time() - t0
                m, s = divmod(t1, 60)
                h, m = divmod(m, 60)
                d, h = divmod(h, 24)
                stdout.write("\rn = %3d,     u = %8.1f cm/s,     K = %8.1f 1/s,     Tmax = %8.1f K,     elaped time: %02d %02d:%02d:%02d"%(
                        tracker[t][0],tracker[t][1],tracker[t][2],tracker[t][3],d, h, m, s))
                stdout.flush()
            file_name = 'extinction_{0:04d}.xml'.format(n)
            oppFlame.save(data_directory + file_name, name='solution', loglevel=0,
                          description='Cantera version ' + ct.__version__ +
                          ', reaction mechanism ' + model)
            T_max.append(np.max(oppFlame.T))
            # CONVERGED?
            #print("\n%6.1f - %6.1f = %5.1f <? %4.2f   &   %f <? %f\n"%(T_max[-2],T_max[-1],T_max[-2] - T_max[-1],delta_T_min,delta_alpha,delta_alpha_min))
            if ((T_max[-2] - T_max[-1] < delta_T_min) &
                    (delta_alpha < delta_alpha_min)):
                if verboseLevel >= 2:
                    print('\nFlame (almost) extinguished at n = {0}.'.format(n),
                          'Abortion criterion satisfied.')
                break
            if n > max_n: # if the solver is having a hard time, restart and increase the initial axial velocity
                print('n is high')
                n = 0
                n_last_burning = 0
                axialVelocity.append(axialVelocity[-1] * axialVelocityIncreaseFactor * vIncCount)
                gas, oppFlame, alpha, delta_alpha, width = initializer(axialVelocity[-1])
                if verboseLevel >= 2:
                    print("\nThis seems to be taking too long... Changing initial axial velocity from %6.1f to %6.1f at n=%d (TrSh1)"%(
                            axialVelocity[-2],axialVelocity[-1],n))
                log.append("\nChanged initial axial velocity from %6.1f to %6.1f at n=%d"%(
                        axialVelocity[-2],axialVelocity[-1],n))
                vIncCount += delta_v_factor
        else: # if extinct
            if delta_alpha >= delta_alpha_low_boundary:
                delta_alpha /= delta_alpha_factor # Reduce relative strain rate increase
                if verboseLevel >= 2:
                    print("\nFlame extinguished at n = %3d. Restoring n = %3d with alpha = %8.2e and delta_alpha = %8.2e (E2)"%(
                          n, n_last_burning, alpha[n_last_burning], delta_alpha))
                if n_last_burning > 0:
                    # Restore last burning solution
                    file_name = 'extinction_{0:04d}.xml'.format(n_last_burning)
                    oppFlame.restore(data_directory + file_name, name='solution', loglevel=0)
                    if SArestoreFile: # save restore file for SA continuation on first reduction of delta_alpha
                        if n_last_burning > 2:
                            file_name0 = 'extinction_{0:04d}.xml'.format(n_last_burning-2)
                        elif n_last_burning == 2:
                            file_name0 = 'extinction_{0:04d}.xml'.format(n_last_burning-1)
                        else:
                            file_name0 = 'extinction_{0:04d}.xml'.format(n_last_burning)
                        copyfile(data_directory + file_name0, data_directory + 'restoreSA.xml')
                        SAalpha = [alpha[n_last_burning-2]]
                        SAdelta_alpha = delta_alpha * delta_alpha_factor
                        SArestoreFile = 0
                else: # haven't ignited yet (n_last_burning = 0)
                    n = 0
                    axialVelocity.append(axialVelocity[-1] / (axialVelocityDecreaseFactor * vDecCount))
                    gas, oppFlame, alpha, delta_alpha, width = initializer(axialVelocity[-1])
                    if verboseLevel >= 2:
                        print("\nCouldn't ignite. Changing initialAxialVelocity from %6.1f to %6.1f at n=%d (TrSh2)"%(
                                axialVelocity[-2],axialVelocity[-1],n))
                    log.append("\nChanged initialAxialVelocity from %6.1f to %6.1f at n=%d"%(
                            axialVelocity[-2],axialVelocity[-1],n))
                    vDecCount -= delta_v_factor
            else: # if delta_alpha is too low, troubleshoot
                if (grid_pnts != 0) & (restoreSwitch == 0):
                    oppFlame = ct.CounterflowTwinPremixedFlame(gas, width=width) #switch to an automated grid size
                    if verboseLevel >= 2:
                        print("\nCouldn't converge by reducint delta alpha, switching to an automated grid size to better estimate the temperature")
                        print("\nRestoring delta_alpha to 0.02 (TrSh3)")
                    log.append("\nSwitched to an automated grid size")
                    delta_alpha = 0.02 # restore delta alpha to a realistic value
                    log.append("\nRestoring delta_alpha to 0.02")
                if (restoreSwitch == 1) & (n_last_burning > 1):
                    n_last_burning -= 1
                    log.append("\nReducing n_last_burning by 1")
                    if verboseLevel >= 2:
                        print("Couldn't converge, reducing n last burning by 1")
                        print("\nFlame extinguished at n = %3d. Restoring n = %3d with alpha = %8.2e and delta_alpha = %8.2e (TrSh4)"%(
                          n, n_last_burning, alpha[n_last_burning], delta_alpha))
                    # Restore last burning solution
                    file_name = 'extinction_{0:04d}.xml'.format(n_last_burning)
                    oppFlame.restore(data_directory + file_name, name='solution', loglevel=0)
                if n > max_n:
                    n = 0
                    n_last_burning = 0
                    axialVelocity.append(axialVelocity[-1] * axialVelocityDecreaseFactor * vDecCount)
                    gas, oppFlame, alpha, delta_alpha, width = initializer(axialVelocity[-1])
                    if verboseLevel >= 2:
                        print("\nThis seems to be taking too long... Let's initialize & reduce the velocity")
                        print("\nChanging initialAxialVelocity from %6.1f to %6.1f at n=%d (TrSh5)"%(
                                axialVelocity[-2],axialVelocity[-1],n))
                    log.append("\nInitialized")
                    log.append("\nChanged initialAxialVelocity from %6.1f to %6.1f at n=%d"%(
                            axialVelocity[-2],axialVelocity[-1],n))
                    vDecCount -= delta_v_factor
                restoreSwitch += 1 # indicate that the number of times troubleshooting was attempted, so different cases could be tried out
        # Update relative strain rates
        alpha.append(alpha[n_last_burning] + delta_alpha)
        strain_factor = alpha[-1] / alpha[n_last_burning]
        normalized_grid = oppFlame.grid / (oppFlame.grid[-1] - oppFlame.grid[0])
        # Update mass fluxes
        oppFlame.reactants.mdot *= strain_factor ** exp_mdot_a
        # Update velocity
        oppFlame.set_profile('u', normalized_grid, oppFlame.u * strain_factor ** exp_u_a)
        # Update pressure curvature
        oppFlame.set_profile('lambda', normalized_grid, oppFlame.L * strain_factor ** exp_lam_a)
    strainRates, strainRatePoint, K = computeStrainRates(oppFlame)
    return K, strainRatePoint, log, n_last_burning, alpha, delta_alpha, grid_pnts, SAalpha, SAdelta_alpha, tracker


def SAsolver(gas, oppFlame, alpha, delta_alpha, width, t0):
    oppFlame.restore(data_directory + 'restoreSA.xml', name='solution', loglevel=0)
    n = -1
    T_max = [np.max(oppFlame.T)]
    n_last_burning = 0
    restoreSwitch = 0
    vIncCount = u_vIncCount
    vDecCount = u_vDecCount
    log = []
    while True:
        strainRates, strainRatePoint, K = computeStrainRates(oppFlame)
        n += 1
        try:
            oppFlame.solve(loglevel=0, refine_grid=refine, auto=True)
        except Exception as e:
            if verboseLevel >= 3:
                print('\nError: Did not converge at n = %3d. alpha = %8.2e,   delta_alppha = %8.2e,   Tmax = %8.1f K'%(
                        n, alpha[-1], delta_alpha, np.max(oppFlame.T)))
        if np.max(oppFlame.T) > temperature_limit_extinction:
            n_last_burning = n
            if verboseLevel >=2:
                t1 = time.time() - t0
                m, s = divmod(t1, 60)
                h, m = divmod(m, 60)
                d, h = divmod(h, 24)
                stdout.write("\rn = %3d,     u = %8.1f cm/s,     K = %8.1f 1/s,     Tmax = %8.1f K,     elaped time: %02d %02d:%02d:%02d"%(
                        n, np.max(oppFlame.u)*100, K, np.max(oppFlame.T),d, h, m, s))
                stdout.flush()
            file_name = 'extinction_{0:04d}.xml'.format(n)
            oppFlame.save(data_directory + file_name, name='solution', loglevel=0,
                          description='Cantera version ' + ct.__version__ +
                          ', reaction mechanism ' + model)
            T_max.append(np.max(oppFlame.T))
            # CONVERGED?
            if ((T_max[-2] - T_max[-1] < delta_T_min) &
                    (delta_alpha < delta_alpha_min)):
                if verboseLevel >= 3:
                    print('\nFlame (almost) extinguished at n = {0}.'.format(n),
                          'Abortion criterion satisfied.')
                break
            if n > max_n:
                print('n is high')
                n = 0
                n_last_burning = 0
                axialVelocity.append(axialVelocity[-1] * axialVelocityIncreaseFactor * vIncCount)
                gas, oppFlame, alpha, delta_alpha, width = initializer(axialVelocity[-1])
                if verboseLevel >= 2:
                    print("\nThis seems to be taking too long... Changing initial axial velocity from %6.1f to %6.1f at n=%d (TrSh1)"%(
                            axialVelocity[-2],axialVelocity[-1],n))
                log.append("\nChanged initial axial velocity from %6.1f to %6.1f at n=%d"%(
                        axialVelocity[-2],axialVelocity[-1],n))
                vIncCount += delta_v_factor
        else: # if extinct
            if delta_alpha >= delta_alpha_low_boundary:
                delta_alpha /= delta_alpha_factor # Reduce relative strain rate increase
                if verboseLevel >= 3:
                    print("\nFlame extinguished at n = %3d. Restoring n = %3d with alpha = %8.2e and delta_alpha = %8.2e (E2)"%(
                          n, n_last_burning, alpha[n_last_burning], delta_alpha))
                if n_last_burning > 0:
                    # Restore last burning solution
                    file_name = 'extinction_{0:04d}.xml'.format(n_last_burning)
                    oppFlame.restore(data_directory + file_name, name='solution', loglevel=0)
                else: # haven't ignited yet (n_last_burning = 0)
                    n = 0
                    axialVelocity.append(axialVelocity[-1] / (axialVelocityDecreaseFactor * vDecCount))
                    gas, oppFlame, alpha, delta_alpha, width = initializer(axialVelocity[-1])
                    if verboseLevel >= 3:
                        print("\nCouldn't ignite. Changing initialAxialVelocity from %6.1f to %6.1f at n=%d (TrSh2)"%(
                                axialVelocity[-2],axialVelocity[-1],n))
                    log.append("\nChanged initialAxialVelocity from %6.1f to %6.1f at n=%d"%(
                            axialVelocity[-2],axialVelocity[-1],n))
                    vDecCount += delta_v_factor
            else: # if delta_alpha is too low, troubleshoot
                if (restoreSwitch == 0):
                    oppFlame = ct.CounterflowTwinPremixedFlame(gas, width=width) #switch to an automated grid size
                    if verboseLevel >= 3:
                        print("\nCouldn't converge by reducint delta alpha, Restoring delta_alpha to 0.02 (TrSh3)")
                    log.append("\nRestored delta_alpha to 0.02")
                    delta_alpha = 0.02 # restore delta alpha to a realistic value
                if (restoreSwitch == 1) & (n_last_burning > 1):
                    n_last_burning -= 1
                    log.append("\nReduced n_last_burning by 1")
                    if verboseLevel >= 3:
                        print("Couldn't converge, reducing n last burning by 1")
                        print("\nFlame extinguished at n = %3d. Restoring n = %3d with alpha = %8.2e and delta_alpha = %8.2e (TrSh4)"%(
                          n, n_last_burning, alpha[n_last_burning], delta_alpha))
                    file_name = 'extinction_{0:04d}.xml'.format(n_last_burning)
                    oppFlame.restore(data_directory + file_name, name='solution', loglevel=0)
                if n > max_n:
                    n = 0
                    n_last_burning = 0
                    axialVelocity.append(axialVelocity[-1] * axialVelocityDecreaseFactor * vDecCount)
                    gas, oppFlame, alpha, delta_alpha, width = initializer(axialVelocity[-1])
                    if verboseLevel >= 3:
                        print("\nThis seems to be taking too long... Let's initialize & reduce the velocity")
                        print("\nChanging initialAxialVelocity from %6.1f to %6.1f at n=%d (TrSh5)"%(
                                axialVelocity[-2],axialVelocity[-1],n))
                    log.append("\nInitialized")
                    log.append("\nChanged initialAxialVelocity from %6.1f to %6.1f at n=%d"%(
                            axialVelocity[-2],axialVelocity[-1],n))
                    vDecCount -= delta_v_factor
                restoreSwitch += 1 # indicate that the number of times troubleshooting was attempted, so different cases could be tried out
        alpha.append(alpha[n_last_burning] + delta_alpha)
        strain_factor = alpha[-1] / alpha[n_last_burning]
        normalized_grid = oppFlame.grid / (oppFlame.grid[-1] - oppFlame.grid[0])
        oppFlame.reactants.mdot *= strain_factor ** exp_mdot_a
        oppFlame.set_profile('u', normalized_grid, oppFlame.u * strain_factor ** exp_u_a)
        oppFlame.set_profile('lambda', normalized_grid, oppFlame.L * strain_factor ** exp_lam_a)
    strainRates, strainRatePoint, K = computeStrainRates(oppFlame)
    return K, log


def printResults(K,oppFlame,density,Sc,d,h,m,s):
    print('---------------------------------------------------------------------------')
    print('Parameters at the extinction point:')
    print('EXTINCTION STRAIN RATE = %8.1f 1/s'%(K))
    print('Tmax = {0:6.1f} K'.format(np.max(oppFlame.T)))
    print('P = {0} bar'.format(oppFlame.P / 1e5))
    print('Axial velocity = %8.1f cm/s'%(np.max(oppFlame.u)*100))
    print("Consumption Speed: {0:.2f} cm/s".format(100*Sc))
    print("Elaped time for normal solution (w/o SA): %02d:%02d:%02d"%(h, m, s))
    print("\n\nTotal elapsed time without SA: %02d days and %02d:%02d:%02d"%(d, h, m, s))
    
    
def stripModelName(model):
    a=i=0
    d=-1
    for c in model:
        if c == '/':
            a=i+1
        elif c == '.':
            d=i
        i+=1
    if d == -1:
        short_model = model[a:]
    else:
        short_model = model[a:d]
    return short_model

def writePrimeToFile(h,m,s,KPrime,oppFlame,Sc,alpha,delta_alpha,grid_pnts,log):
    short_model = stripModelName(model)  
    t = time.strftime("%Y-%m-%d %H-%M-%S", time.localtime())
    logFile = 'ESR_Results/{0} {1} {2}.txt'.format(t,short_model,name)
    file1 = open(logFile,'a')
    file1.write('{0}\n'.format(t))
    file1.write('Premixed twin axisemetric Extinction Strain Rate script\n')
    file1.write('Elapsed time: %02d:%02d:%02d\n'%(h, m, s))
    file1.write('\nComposition: {0}\n'.format(composition))
    file1.write('\nParameters at the extinction point:\n')
    file1.write('EXTINCTION STRAIN RATE = %.1f 1/s\n'%(KPrime))
    file1.write('Tmax =                   %.1f K\n'%(np.max(oppFlame.T)))
    file1.write('P =                      %.1f bar\n'%(oppFlame.P / 1e5))
    file1.write('Axial velocity =         %.1f cm/s\n'%(np.max(oppFlame.u)*100))
    file1.write('Consumption Speed:       %.1f cm/s\n'%(100*Sc))
    file1.write('\nCalculation parameters:\n')
    file1.write('Last alpha:             {0}\n'.format(alpha[n_last_burning]))
    file1.write('Last delta alpha:       {0}'.format(delta_alpha))
    file1.write('\n\nUser parameters:\n')
    file1.write('Mechanism =              %s\n'%(short_model))
    file1.write('Initial axial velocity = %.0f cm/s\n'%(initialAxialVelocity))
    file1.write('Inlet T & P =            %d K, %d bar\n'%(To, Po / 1e5))
    file1.write('Half width =             %.2f cm\n'%(half_width))
    if grid_pnts == 0:
        file1.write('Grid points =            automatically determined\n')
    else:
        file1.write('Grid points =            %d\n'%(grid_pnts))
    file1.write('Refine =                 {0}\n'.format(refine))
    file1.write('Transport =              %s\n'%(tran))
    file1.write('Extinction T limit =     %d K\n'%(temperature_limit_extinction))
    file1.write('Delta T min (conv)=      %.2f K\n'%(delta_T_min))
    file1.write('Initial alpha =          %.2f\n'%(u_alpha[0]))
    file1.write('Initial delta alpha =    %.2f\n'%(u_delta_alpha))
    file1.write('Delta alpha factor =     %d\n'%(delta_alpha_factor))
    file1.write('Delta alpha min (conv) = %.10f\n'%(delta_alpha_min))
    file1.write('Ratio =                  %.2f\n'%(ratio))
    file1.write('Slope =                  %.2f\n'%(slope))
    file1.write('Curve =                  %.2f\n'%(curve))
    file1.write('Prune =                  %.2f\n'%(prune))
    file1.write('SA perturbation          %.2f\n'%(dk))
    if len(log) > 0:
        file1.write('\n\nSummary of troubleshooting attempts:\n')
        for i in range(len(log)):
            file1.write('%d. \n'%(i+1))
            file1.write(log[i])
    file1.close()
    if verboseLevel >= 2:
        print('Solution saved to file.\n')
    return logFile

def appendLog(logFile,log,r,rxn):
    file1 = open(logFile,'a')
    file1.write('\nSA troubleshooting for reaction number %d, %s:\n'%(r,rxn))
    for i in range(len(log)):
        file1.write('%d.   %s\n'%(i+1,log[i]))
    file1.close()

def logSA(logFile,SA,rxnList):
    file1 = open(logFile,'a')
    file1.write('\n\nSA DATA:\n')
    file1.write("#     n-SA coef,  reaction\n")
    file1.write("--------------------------\n")
    for i in range(len(rxnList)):
        file1.write("%03d  %10.2e,  %s\n"%(i,SA[i],rxnList[i]))
    file1.close()
    
def plotFigs(oppFlame,strainRatePoint,n,u0,K_tot,T_max,file_name,n_last_burning):
    
    if (species1 == '') & (species2 ==''):
        plt.figure(figsize=(12,12))
        sub=3
    else:
        plt.figure(figsize=(12,18))
        sub=4
    plt.subplot(sub,2,1)
    plt.plot(oppFlame.grid*100, oppFlame.u*100, 'r-o', lw=2)
    plt.xlim(oppFlame.grid[0]*100, oppFlame.grid[-1]*100)
    plt.ylim(0, max(oppFlame.u)*105)
    plt.xlabel('Distance (cm)')
    plt.ylabel('Axial Velocity (cm/s)')
    plt.title('Axial velocity profile')
    plt.plot(oppFlame.grid[strainRatePoint]*100, oppFlame.u[strainRatePoint]*100,'gs')
    plt.annotate('ESR point',
                xy=(oppFlame.grid[strainRatePoint]*100, oppFlame.u[strainRatePoint]*100),
                xytext=(oppFlame.grid[-1]*10, max(oppFlame.u)*10),
                arrowprops={'arrowstyle':'->'})
    plt.subplot(sub,2,2)
    plt.plot(oppFlame.grid*100, oppFlame.T, 'g-o', lw=2)
    plt.xlim(oppFlame.grid[0]*100, oppFlame.grid[-1]*100)
    plt.ylim(0, 2000)
    plt.xlabel('Distance (cm)')
    plt.ylabel('Temperature (K)')
    plt.title('T Profile for n = %02d'%(n_last_burning))
    plt.subplot(sub,2,3)
    plt.plot(K_tot, T_max,'b-o', lw=2)
    plt.xlabel('ESR (1/s)')
    plt.ylabel(r'$T_{max}$ (K)')
    plt.title('Tmax vs. ESR')
    plt.subplot(sub,2,4)
    plt.plot(u0, T_max, 'k-o', lw=2)
    plt.xlabel('Axial Velocity (cm/s)')
    plt.ylabel('Tmax (K)')
    plt.title('Tmax vs. axial velocity')
    plt.subplot(sub,2,5)
    plt.plot(n, K_tot,'b-o', lw=2)
    plt.xlim(0, n[-1]+0.5)
    plt.xlabel('Iteration number')
    plt.ylabel('Strain rate (1/s)')
    plt.title('Strain rate vs. iteration')
    plt.plot(n[-1], K_tot[-1],'go')
    plt.annotate('ESR point',
                xy=(n[-1], K_tot[-1]),
                xytext=(n[-1]*0.7, K_tot[-1]*0.6),
                arrowprops={'arrowstyle':'->'})
    plt.subplot(sub,2,6) 
    plt.plot(n, T_max, 'k-o', lw=2)
    plt.xlim(0, n[-1]+0.5)
    plt.xlabel('Iteration number')
    plt.ylabel('Tmax (K)')
    plt.title('Tmax vs. iteration')
    if sub == 4:
        plt.subplot(sub,2,7)
        plt.plot(oppFlame.grid*100,oppFlame.X[gas.species_index(species1)])
        plt.xlabel('Distance (cm)')
        plt.ylabel('Mole fraction')
        plt.title('Concentration profile for %s'%(species1))
        plt.subplot(sub,2,8)
        plt.plot(oppFlame.grid*100,oppFlame.X[gas.species_index(species2)])
        plt.xlabel('Distance (cm)')
        plt.ylabel('Mole fraction')
        plt.title('Concentration profile for %s'%(species2))
    plt.tight_layout
    if verboseLevel >= 3:
        plt.show()
    fig_name = file_name[0:-3] + str('png')
    plt.savefig(fig_name, dpi = 100)
    if verboseLevel >= 2:
        print('\nFigure saved to file.')

def extractTopSA(logFile,SA,rxnList,d,h,m,s):
    num1 = np.linspace(0,len(SA)-1,len(SA))
    num1 = list(zip(SA,num1))
    num1.sort(key=lambda x: abs(x[0]), reverse=True)
    SA_sorted = []
    rxns_sorted = []
    for i in range(topSA):
        SA_sorted.append(SA[int(num1[i][1])])
        rxns_sorted.append(rxnList[int(num1[i][1])])
    print("\n\n\n Sorted Top SA coefficients:")
    file1 = open(logFile,'a')
    file1.write('\n\n\n Sorted Top SA coefficients:')
    file1.write("\n#     n-SA coef,  reaction")
    file1.write("\n--------------------------\n")
    for i in range(topSA):
        print("%03d  %10.2e,  %s"%(i,SA_sorted[i],rxns_sorted[i]))
        file1.write("%03d  %10.2e,  %s\n"%(i,SA_sorted[i],rxns_sorted[i]))
    file1.write("\n\nTotal elapsed time with SA: %02d days and %02d:%02d:%02d"%(d, h, m, s))
    print("\n\nTotal elapsed time with SA: %02d days and %02d:%02d:%02d"%(d, h, m, s))
    file1.close()
    return SA_sorted, rxns_sorted
        
#graphical definitions
plt.rcParams['figure.autolayout'] = True
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['legend.fontsize'] = 10
plt.rcParams['figure.facecolor'] = 'white'
plt.rcParams['figure.figsize'] = (8,6)

# Create directories for output files
data_directory = u_data_directory
if not os.path.exists(data_directory):
    os.makedirs(data_directory)
results_directory = 'ESR_results/'
if not os.path.exists(results_directory):
    os.makedirs(results_directory)
    
# Correct user input
if initialAxialVelocity <= 0:
    initialAxialVelocity = 10
    print("initialAxialVelocity is not allowed to be 0 or less. Was auto-set to 10 cm/s")
if (grid_pnts == 1) | (grid_pnts < 0):
    grid_pnts == 0
    print("grid_pnts parameter is not allowed to be 1 or negative. Was auto-set to 0 (automatic)")
    
print("OK")
# Out:
# OK

# %% [markdown]
# # Main

# %%
t0 = time.time()   # set timer
# initialize parameters from user input
gas, oppFlame, alpha, delta_alpha, width = initializer(initialAxialVelocity)

KPrime,strainRatePoint,log,n_last_burning,alpha,delta_alpha,grid_pnts,SAalpha,SAd_alpha,tracker = solver(
    gas, oppFlame, alpha, delta_alpha, width, t0)

Sc = computeConsumptionSpeed(oppFlame)

t1 = time.time() - t0
m, s = divmod(t1, 60)
h, m = divmod(m, 60)
d, h = divmod(h, 24)
if verboseLevel >= 1:
    printResults(KPrime, oppFlame, gas.density, Sc, d, h, m, s)

logFile = writePrimeToFile(h, m, s, KPrime, oppFlame, Sc, alpha, delta_alpha, grid_pnts,log)

plotFigs(oppFlame,strainRatePoint,column(tracker, 0),column(tracker, 1),column(tracker, 2),column(tracker, 3),
         logFile,n_last_burning)  # Tracker: n, u0, ESR, Tmax

if topSA > 0:
    rxnList = ct.Reaction.listFromFile(model)
    SA = [] # the normalized SA coefficients
    for i in range(gas.n_reactions):
        if verboseLevel >= 2:
            print("\nConducting SA for rxn %d out of %d: %s\n"%(
                    i, gas.n_reactions-1, rxnList[i]))
        gas, oppFlame, alpha, delta_alpha, width = initializer(initialAxialVelocity)
        gas.set_multiplier(1.0)      # reset all multipliers
        APrime = gas.forward_rate_constants[i]
        gas.set_multiplier(dk, i)    # perturb reaction i by a factor of dk
        K, log = SAsolver(
            gas, oppFlame, SAalpha, SAd_alpha, width, t0)
        if len(log) >= 1:
            appendLog(logFile,log,i,rxnList[i])
        dlnKdlnAi = ((K - KPrime) / (gas.forward_rate_constants[i] - APrime)) * (APrime / KPrime)
        if verboseLevel >= 2:
            print("\n**** ... done. Rxn %03d  '%s' has a normalized SA coefficient of %10.2e ****\n"%(
                    i,rxnList[i],dlnKdlnAi))
        SA.append(dlnKdlnAi)
    logSA(logFile,SA,rxnList)

    t2 = time.time() - t0
    m, s = divmod(t2, 60)
    h, m = divmod(m, 60)
    d, h = divmod(h, 24)

    SA_sorted, rxns_sorted = extractTopSA(logFile,SA,rxnList,d,h,m,s)

# plot topSA + legend

print("Done.")
# Out:
# Solving xo1247R with u0 =  200.0 cm/s:
# n =   8,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.3 K,     elaped time: 00 00:00:28
# Flame extinguished at n =   9. Restoring n =   8 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  38,     u =    619.0 cm/s,     K =   1715.4 1/s,     Tmax =   1770.2 K,     elaped time: 00 00:02:28
# Error: Did not converge at n =  39. alpha = 9.60e+00,   delta_alppha = 2.00e-02,   Tmax =   1769.1 K
# n =  39,     u =    619.7 cm/s,     K =   1717.0 1/s,     Tmax =   1769.1 K,     elaped time: 00 00:03:04
# Error: Did not converge at n =  40. alpha = 9.62e+00,   delta_alppha = 2.00e-02,   Tmax =   1767.8 K
# n =  43,     u =    622.3 cm/s,     K =   1723.4 1/s,     Tmax =   1762.8 K,     elaped time: 00 00:06:50
# Flame extinguished at n =  44. Restoring n =  43 with alpha = 9.68e+00 and delta_alpha = 4.00e-04 (E2)
# n =  45,     u =    622.3 cm/s,     K =   1723.2 1/s,     Tmax =   1762.8 K,     elaped time: 00 00:08:28
# Flame (almost) extinguished at n = 45. Abortion criterion satisfied.
# ---------------------------------------------------------------------------
# Parameters at the extinction point:
# EXTINCTION STRAIN RATE =   1723.2 1/s
# Tmax = 1762.8 K
# P = 1.01325 bar
# Axial velocity =    622.3 cm/s
# Consumption Speed: 23.49 cm/s
# Elaped time for normal solution (w/o SA): 00:08:29
#
#
# Total elapsed time without SA: 00 days and 00:08:29
# Solution saved to file.
# <div id='28c3f14b-2045-47e7-88fe-250f202e3fa7'></div>
# Figure saved to file.
#
# Conducting SA for rxn 0 out of 73: CH3(18) + H(4) (+M) <=> CH4(1) (+M)
#
# n =   2,     u =    600.0 cm/s,     K =   1666.6 1/s,     Tmax =   1732.9 K,     elaped time: 00 00:08:43
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  25,     u =    614.5 cm/s,     K =   1702.1 1/s,     Tmax =   1747.5 K,     elaped time: 00 00:10:19
# Error: Did not converge at n =  26. alpha = 9.46e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.1 K
# n =  31,     u =    618.4 cm/s,     K =   1711.7 1/s,     Tmax =   1760.2 K,     elaped time: 00 00:12:48
# Flame extinguished at n =  32. Restoring n =  31 with alpha = 9.56e+00 and delta_alpha = 4.00e-04 (E2)
#
# Flame extinguished at n =  33. Restoring n =  31 with alpha = 9.56e+00 and delta_alpha = 8.00e-06 (E2)
# n =  34,     u =    618.4 cm/s,     K =   1710.9 1/s,     Tmax =   1760.2 K,     elaped time: 00 00:17:17
# Flame (almost) extinguished at n = 34. Abortion criterion satisfied.
#
# **** ... done. Rxn 000  'CH3(18) + H(4) (+M) <=> CH4(1) (+M)' has a normalized SA coefficient of   7.30e-03 ****
#
#
# Conducting SA for rxn 1 out of 73: H(4) + O2(2) (+M) <=> HO2(10) (+M)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.1 1/s,     Tmax =   1788.1 K,     elaped time: 00 00:17:30
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  25,     u =    614.5 cm/s,     K =   1702.9 1/s,     Tmax =   1773.3 K,     elaped time: 00 00:18:56
# Error: Did not converge at n =  26. alpha = 9.46e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.2 K
# n =  27,     u =    615.8 cm/s,     K =   1706.3 1/s,     Tmax =   1771.1 K,     elaped time: 00 00:20:00
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1769.9 K
# n =  32,     u =    619.0 cm/s,     K =   1714.2 1/s,     Tmax =   1761.6 K,     elaped time: 00 00:23:07
# Flame extinguished at n =  33. Restoring n =  32 with alpha = 9.58e+00 and delta_alpha = 4.00e-04 (E2)
# n =  34,     u =    619.0 cm/s,     K =   1713.8 1/s,     Tmax =   1761.5 K,     elaped time: 00 00:24:17
# Flame (almost) extinguished at n = 34. Abortion criterion satisfied.
#
# **** ... done. Rxn 001  'H(4) + O2(2) (+M) <=> HO2(10) (+M)' has a normalized SA coefficient of   5.81e-03 ****
#
#
# Conducting SA for rxn 2 out of 73: CH3(18) + HO2(10) <=> CH4(1) + O2(2)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.3 1/s,     Tmax =   1788.3 K,     elaped time: 00 00:24:29
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  29,     u =    617.1 cm/s,     K =   1710.0 1/s,     Tmax =   1770.5 K,     elaped time: 00 00:26:29
# Error: Did not converge at n =  30. alpha = 9.54e+00,   delta_alppha = 2.00e-02,   Tmax =   1769.4 K
# n =  31,     u =    618.4 cm/s,     K =   1713.3 1/s,     Tmax =   1769.0 K,     elaped time: 00 00:28:39
# Error: Did not converge at n =  32. alpha = 9.58e+00,   delta_alppha = 2.00e-02,   Tmax =   1767.8 K
# n =  35,     u =    621.0 cm/s,     K =   1719.7 1/s,     Tmax =   1762.6 K,     elaped time: 00 00:31:15
# Flame extinguished at n =  36. Restoring n =  35 with alpha = 8.00e+00 and delta_alpha = 4.00e-04 (E2)
# n =  37,     u =    621.0 cm/s,     K =   1719.5 1/s,     Tmax =   1762.5 K,     elaped time: 00 00:32:31
# Flame (almost) extinguished at n = 37. Abortion criterion satisfied.
#
# **** ... done. Rxn 002  'CH3(18) + HO2(10) <=> CH4(1) + O2(2)' has a normalized SA coefficient of   1.10e-02 ****
#
#
# Conducting SA for rxn 3 out of 73: H2(7) + M <=> 2 H(4) + M
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.6 K,     elaped time: 00 00:32:44
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.7 1/s,     Tmax =   1773.1 K,     elaped time: 00 00:34:20
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.2 K
# n =  28,     u =    616.4 cm/s,     K =   1708.3 1/s,     Tmax =   1772.2 K,     elaped time: 00 00:34:51
# Error: Did not converge at n =  29. alpha = 9.52e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.2 K
# n =  30,     u =    617.7 cm/s,     K =   1711.7 1/s,     Tmax =   1770.0 K,     elaped time: 00 00:35:30
# Error: Did not converge at n =  31. alpha = 9.56e+00,   delta_alppha = 2.00e-02,   Tmax =   1768.8 K
# n =  35,     u =    621.0 cm/s,     K =   1719.6 1/s,     Tmax =   1760.0 K,     elaped time: 00 00:38:38
# Flame extinguished at n =  36. Restoring n =  35 with alpha = 8.00e+00 and delta_alpha = 4.00e-04 (E2)
# n =  37,     u =    621.0 cm/s,     K =   1719.2 1/s,     Tmax =   1759.8 K,     elaped time: 00 00:39:51
# Flame (almost) extinguished at n = 37. Abortion criterion satisfied.
#
# **** ... done. Rxn 003  'H2(7) + M <=> 2 H(4) + M' has a normalized SA coefficient of  -5.03e-65 ****
#
#
# Conducting SA for rxn 4 out of 73: H(4) + HO2(10) <=> H2(7) + O2(2)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.3 1/s,     Tmax =   1788.0 K,     elaped time: 00 00:40:04
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  26,     u =    615.1 cm/s,     K =   1704.8 1/s,     Tmax =   1772.9 K,     elaped time: 00 00:41:36
# Error: Did not converge at n =  27. alpha = 9.48e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.9 K
# n =  33,     u =    619.7 cm/s,     K =   1716.2 1/s,     Tmax =   1763.0 K,     elaped time: 00 00:45:09
# Flame extinguished at n =  34. Restoring n =  33 with alpha = 9.56e+00 and delta_alpha = 4.00e-04 (E2)
# n =  35,     u =    619.7 cm/s,     K =   1715.9 1/s,     Tmax =   1762.9 K,     elaped time: 00 00:46:08
# Flame (almost) extinguished at n = 35. Abortion criterion satisfied.
#
# **** ... done. Rxn 004  'H(4) + HO2(10) <=> H2(7) + O2(2)' has a normalized SA coefficient of  -9.21e-04 ****
#
#
# Conducting SA for rxn 5 out of 73: CH4(1) + H(4) <=> CH3(18) + H2(7)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.1 1/s,     Tmax =   1787.2 K,     elaped time: 00 00:46:20
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  26,     u =    615.1 cm/s,     K =   1704.6 1/s,     Tmax =   1771.8 K,     elaped time: 00 00:48:06
# Error: Did not converge at n =  27. alpha = 9.48e+00,   delta_alppha = 2.00e-02,   Tmax =   1770.8 K
# n =  28,     u =    616.4 cm/s,     K =   1708.0 1/s,     Tmax =   1769.7 K,     elaped time: 00 00:48:51
# Error: Did not converge at n =  29. alpha = 9.52e+00,   delta_alppha = 2.00e-02,   Tmax =   1768.4 K
# n =  33,     u =    619.7 cm/s,     K =   1715.9 1/s,     Tmax =   1759.2 K,     elaped time: 00 00:53:00
# Flame extinguished at n =  34. Restoring n =  33 with alpha = 9.56e+00 and delta_alpha = 4.00e-04 (E2)
# n =  35,     u =    619.7 cm/s,     K =   1715.4 1/s,     Tmax =   1759.0 K,     elaped time: 00 00:54:14
# Flame (almost) extinguished at n = 35. Abortion criterion satisfied.
#
# **** ... done. Rxn 005  'CH4(1) + H(4) <=> CH3(18) + H2(7)' has a normalized SA coefficient of  -8.37e-11 ****
#
#
# Conducting SA for rxn 6 out of 73: H(4) + HO2(10) <=> 2 OH(6)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.3 1/s,     Tmax =   1788.3 K,     elaped time: 00 00:54:26
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  26,     u =    615.1 cm/s,     K =   1704.9 1/s,     Tmax =   1773.4 K,     elaped time: 00 00:55:56
# Error: Did not converge at n =  27. alpha = 9.48e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.4 K
# n =  27,     u =    615.8 cm/s,     K =   1706.5 1/s,     Tmax =   1772.4 K,     elaped time: 00 00:56:28
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.4 K
# n =  29,     u =    617.1 cm/s,     K =   1709.9 1/s,     Tmax =   1770.3 K,     elaped time: 00 00:57:08
# Error: Did not converge at n =  30. alpha = 9.54e+00,   delta_alppha = 2.00e-02,   Tmax =   1769.1 K
# n =  34,     u =    620.3 cm/s,     K =   1717.8 1/s,     Tmax =   1760.0 K,     elaped time: 00 01:00:19
# Flame extinguished at n =  35. Restoring n =  34 with alpha = 9.56e+00 and delta_alpha = 4.00e-04 (E2)
# n =  36,     u =    620.3 cm/s,     K =   1717.3 1/s,     Tmax =   1759.8 K,     elaped time: 00 01:01:45
# Flame (almost) extinguished at n = 36. Abortion criterion satisfied.
#
# **** ... done. Rxn 006  'H(4) + HO2(10) <=> 2 OH(6)' has a normalized SA coefficient of  -5.77e-03 ****
#
#
# Conducting SA for rxn 7 out of 73: H(4) + O2(2) <=> O(5) + OH(6)
#
# n =   3,     u =    632.5 cm/s,     K =   1758.4 1/s,     Tmax =   1780.9 K,     elaped time: 00 01:02:00
# Flame extinguished at n =   4. Restoring n =   3 with alpha = 1.00e+01 and delta_alpha = 2.00e-02 (E2)
# n =  19,     u =    642.8 cm/s,     K =   1782.8 1/s,     Tmax =   1769.5 K,     elaped time: 00 01:03:06
# Error: Did not converge at n =  20. alpha = 9.34e+00,   delta_alppha = 2.00e-02,   Tmax =   1768.4 K
# n =  25,     u =    646.9 cm/s,     K =   1793.2 1/s,     Tmax =   1760.1 K,     elaped time: 00 01:07:20
# Flame extinguished at n =  26. Restoring n =  25 with alpha = 9.44e+00 and delta_alpha = 4.00e-04 (E2)
# n =  27,     u =    647.0 cm/s,     K =   1792.8 1/s,     Tmax =   1760.0 K,     elaped time: 00 01:08:21
# Flame (almost) extinguished at n = 27. Abortion criterion satisfied.
#
# **** ... done. Rxn 007  'H(4) + O2(2) <=> O(5) + OH(6)' has a normalized SA coefficient of   2.15e-11 ****
#
#
# Conducting SA for rxn 8 out of 73: H2(7) + O(5) <=> H(4) + OH(6)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.7 K,     elaped time: 00 01:08:32
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.7 1/s,     Tmax =   1773.3 K,     elaped time: 00 01:10:08
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.3 K
# n =  28,     u =    616.4 cm/s,     K =   1708.4 1/s,     Tmax =   1772.3 K,     elaped time: 00 01:10:40
# Error: Did not converge at n =  29. alpha = 9.52e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.3 K
# n =  30,     u =    617.7 cm/s,     K =   1711.8 1/s,     Tmax =   1770.2 K,     elaped time: 00 01:11:28
# Error: Did not converge at n =  31. alpha = 9.56e+00,   delta_alppha = 2.00e-02,   Tmax =   1769.0 K
# n =  36,     u =    621.7 cm/s,     K =   1721.9 1/s,     Tmax =   1761.2 K,     elaped time: 00 01:16:13
# Flame extinguished at n =  37. Restoring n =  36 with alpha = 9.00e+00 and delta_alpha = 4.00e-04 (E2)
# n =  38,     u =    621.8 cm/s,     K =   1721.5 1/s,     Tmax =   1761.2 K,     elaped time: 00 01:17:10
# Flame (almost) extinguished at n = 38. Abortion criterion satisfied.
#
# **** ... done. Rxn 008  'H2(7) + O(5) <=> H(4) + OH(6)' has a normalized SA coefficient of  -1.43e-08 ****
#
#
# Conducting SA for rxn 9 out of 73: H2(7) + O(5) <=> H(4) + OH(6)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1789.0 K,     elaped time: 00 01:17:22
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  28,     u =    616.4 cm/s,     K =   1708.4 1/s,     Tmax =   1773.0 K,     elaped time: 00 01:19:00
# Error: Did not converge at n =  29. alpha = 9.52e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.0 K
# n =  29,     u =    617.1 cm/s,     K =   1710.1 1/s,     Tmax =   1772.0 K,     elaped time: 00 01:19:32
# Error: Did not converge at n =  30. alpha = 9.54e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.0 K
# n =  35,     u =    621.0 cm/s,     K =   1719.8 1/s,     Tmax =   1763.3 K,     elaped time: 00 01:22:05
# Flame extinguished at n =  36. Restoring n =  35 with alpha = 8.00e+00 and delta_alpha = 4.00e-04 (E2)
# n =  37,     u =    621.0 cm/s,     K =   1719.6 1/s,     Tmax =   1763.2 K,     elaped time: 00 01:23:09
# Flame (almost) extinguished at n = 37. Abortion criterion satisfied.
#
# **** ... done. Rxn 009  'H2(7) + O(5) <=> H(4) + OH(6)' has a normalized SA coefficient of  -5.00e-15 ****
#
#
# Conducting SA for rxn 10 out of 73: 2 O(5) + M <=> O2(2) + M
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.6 K,     elaped time: 00 01:23:21
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.7 1/s,     Tmax =   1773.2 K,     elaped time: 00 01:24:57
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.2 K
# n =  30,     u =    617.7 cm/s,     K =   1711.7 1/s,     Tmax =   1770.1 K,     elaped time: 00 01:26:11
# Error: Did not converge at n =  31. alpha = 9.56e+00,   delta_alppha = 2.00e-02,   Tmax =   1768.9 K
# n =  35,     u =    621.0 cm/s,     K =   1719.7 1/s,     Tmax =   1760.5 K,     elaped time: 00 01:29:40
# Flame extinguished at n =  36. Restoring n =  35 with alpha = 8.00e+00 and delta_alpha = 4.00e-04 (E2)
# n =  37,     u =    621.0 cm/s,     K =   1719.2 1/s,     Tmax =   1760.3 K,     elaped time: 00 01:30:39
# Flame (almost) extinguished at n = 37. Abortion criterion satisfied.
#
# **** ... done. Rxn 010  '2 O(5) + M <=> O2(2) + M' has a normalized SA coefficient of   2.83e-03 ****
#
#
# Conducting SA for rxn 11 out of 73: H(4) + O(5) + M <=> OH(6) + M
#
# n =   2,     u =    600.0 cm/s,     K =   1667.3 1/s,     Tmax =   1788.5 K,     elaped time: 00 01:30:51
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.6 1/s,     Tmax =   1772.9 K,     elaped time: 00 01:32:24
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.0 K
# n =  34,     u =    620.3 cm/s,     K =   1718.0 1/s,     Tmax =   1763.1 K,     elaped time: 00 01:34:35
# Flame extinguished at n =  35. Restoring n =  34 with alpha = 9.56e+00 and delta_alpha = 4.00e-04 (E2)
# n =  36,     u =    620.3 cm/s,     K =   1717.8 1/s,     Tmax =   1763.1 K,     elaped time: 00 01:36:02
# Flame (almost) extinguished at n = 36. Abortion criterion satisfied.
#
# **** ... done. Rxn 011  'H(4) + O(5) + M <=> OH(6) + M' has a normalized SA coefficient of   3.43e-03 ****
#
#
# Conducting SA for rxn 12 out of 73: HO2(10) + O(5) <=> O2(2) + OH(6)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.5 K,     elaped time: 00 01:36:14
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.6 1/s,     Tmax =   1773.0 K,     elaped time: 00 01:37:47
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.0 K
# n =  28,     u =    616.4 cm/s,     K =   1708.3 1/s,     Tmax =   1772.0 K,     elaped time: 00 01:38:20
# Error: Did not converge at n =  29. alpha = 9.52e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.0 K
# n =  30,     u =    617.7 cm/s,     K =   1711.7 1/s,     Tmax =   1769.8 K,     elaped time: 00 01:39:05
# Error: Did not converge at n =  31. alpha = 9.56e+00,   delta_alppha = 2.00e-02,   Tmax =   1768.6 K
# n =  34,     u =    620.3 cm/s,     K =   1718.0 1/s,     Tmax =   1763.4 K,     elaped time: 00 01:41:45
# Flame extinguished at n =  35. Restoring n =  34 with alpha = 9.56e+00 and delta_alpha = 4.00e-04 (E2)
# n =  36,     u =    620.3 cm/s,     K =   1717.8 1/s,     Tmax =   1763.3 K,     elaped time: 00 01:43:04
# Flame (almost) extinguished at n = 36. Abortion criterion satisfied.
#
# **** ... done. Rxn 012  'HO2(10) + O(5) <=> O2(2) + OH(6)' has a normalized SA coefficient of   7.17e-03 ****
#
#
# Conducting SA for rxn 13 out of 73: CH4(1) + O(5) <=> CH3(18) + OH(6)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.3 1/s,     Tmax =   1788.2 K,     elaped time: 00 01:43:17
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  26,     u =    615.1 cm/s,     K =   1704.8 1/s,     Tmax =   1773.2 K,     elaped time: 00 01:44:48
# Error: Did not converge at n =  27. alpha = 9.48e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.2 K
# n =  33,     u =    619.7 cm/s,     K =   1716.2 1/s,     Tmax =   1763.4 K,     elaped time: 00 01:47:21
# Flame extinguished at n =  34. Restoring n =  33 with alpha = 9.56e+00 and delta_alpha = 4.00e-04 (E2)
# n =  35,     u =    619.7 cm/s,     K =   1715.9 1/s,     Tmax =   1763.3 K,     elaped time: 00 01:48:27
# Flame (almost) extinguished at n = 35. Abortion criterion satisfied.
#
# **** ... done. Rxn 013  'CH4(1) + O(5) <=> CH3(18) + OH(6)' has a normalized SA coefficient of  -1.87e-09 ****
#
#
# Conducting SA for rxn 14 out of 73: O(5) + OH(6) <=> HO2(10)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.6 K,     elaped time: 00 01:48:39
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.7 1/s,     Tmax =   1773.1 K,     elaped time: 00 01:50:14
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.2 K
# n =  30,     u =    617.7 cm/s,     K =   1711.7 1/s,     Tmax =   1770.0 K,     elaped time: 00 01:51:20
# Error: Did not converge at n =  31. alpha = 9.56e+00,   delta_alppha = 2.00e-02,   Tmax =   1768.8 K
# n =  35,     u =    621.0 cm/s,     K =   1719.6 1/s,     Tmax =   1759.8 K,     elaped time: 00 01:55:16
# Flame extinguished at n =  36. Restoring n =  35 with alpha = 8.00e+00 and delta_alpha = 4.00e-04 (E2)
# n =  37,     u =    621.0 cm/s,     K =   1719.1 1/s,     Tmax =   1759.6 K,     elaped time: 00 01:56:27
# Flame (almost) extinguished at n = 37. Abortion criterion satisfied.
#
# **** ... done. Rxn 014  'O(5) + OH(6) <=> HO2(10)' has a normalized SA coefficient of   2.48e-03 ****
#
#
# Conducting SA for rxn 15 out of 73: H2(7) + OH(6) <=> H(4) + H2O(8)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.7 1/s,     Tmax =   1790.4 K,     elaped time: 00 01:56:40
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  31,     u =    618.4 cm/s,     K =   1713.9 1/s,     Tmax =   1772.7 K,     elaped time: 00 01:58:32
# Error: Did not converge at n =  32. alpha = 9.58e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.7 K
# n =  32,     u =    619.0 cm/s,     K =   1715.6 1/s,     Tmax =   1771.7 K,     elaped time: 00 01:59:05
# Error: Did not converge at n =  33. alpha = 9.60e+00,   delta_alppha = 2.00e-02,   Tmax =   1770.7 K
# n =  38,     u =    623.1 cm/s,     K =   1725.6 1/s,     Tmax =   1761.0 K,     elaped time: 00 02:01:53
# Flame extinguished at n =  39. Restoring n =  38 with alpha = 9.02e+00 and delta_alpha = 4.00e-04 (E2)
# n =  40,     u =    623.1 cm/s,     K =   1725.2 1/s,     Tmax =   1760.9 K,     elaped time: 00 02:02:58
# Flame (almost) extinguished at n = 40. Abortion criterion satisfied.
#
# **** ... done. Rxn 015  'H2(7) + OH(6) <=> H(4) + H2O(8)' has a normalized SA coefficient of   6.42e-07 ****
#
#
# Conducting SA for rxn 16 out of 73: 2 OH(6) <=> H2O(8) + O(5)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.8 K,     elaped time: 00 02:03:10
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  28,     u =    616.4 cm/s,     K =   1708.4 1/s,     Tmax =   1772.7 K,     elaped time: 00 02:04:50
# Error: Did not converge at n =  29. alpha = 9.52e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.7 K
# n =  30,     u =    617.7 cm/s,     K =   1711.8 1/s,     Tmax =   1770.6 K,     elaped time: 00 02:05:33
# Error: Did not converge at n =  31. alpha = 9.56e+00,   delta_alppha = 2.00e-02,   Tmax =   1769.5 K
# n =  32,     u =    619.0 cm/s,     K =   1715.1 1/s,     Tmax =   1769.2 K,     elaped time: 00 02:07:54
# Error: Did not converge at n =  33. alpha = 9.60e+00,   delta_alppha = 2.00e-02,   Tmax =   1767.9 K
# n =  36,     u =    621.7 cm/s,     K =   1722.0 1/s,     Tmax =   1762.4 K,     elaped time: 00 02:11:07
# Flame extinguished at n =  37. Restoring n =  36 with alpha = 9.00e+00 and delta_alpha = 4.00e-04 (E2)
# n =  38,     u =    621.8 cm/s,     K =   1721.7 1/s,     Tmax =   1762.3 K,     elaped time: 00 02:12:16
# Flame (almost) extinguished at n = 38. Abortion criterion satisfied.
#
# **** ... done. Rxn 016  '2 OH(6) <=> H2O(8) + O(5)' has a normalized SA coefficient of  -2.05e-04 ****
#
#
# Conducting SA for rxn 17 out of 73: H2O(8) + M <=> H(4) + OH(6) + M
#
# n =   2,     u =    600.0 cm/s,     K =   1667.3 1/s,     Tmax =   1788.4 K,     elaped time: 00 02:12:28
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.5 1/s,     Tmax =   1772.6 K,     elaped time: 00 02:14:03
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.6 K
# n =  29,     u =    617.1 cm/s,     K =   1709.9 1/s,     Tmax =   1770.5 K,     elaped time: 00 02:15:11
# Error: Did not converge at n =  30. alpha = 9.54e+00,   delta_alppha = 2.00e-02,   Tmax =   1769.3 K
# n =  31,     u =    618.4 cm/s,     K =   1713.2 1/s,     Tmax =   1746.7 K,     elaped time: 00 02:17:17
# Error: Did not converge at n =  32. alpha = 9.58e+00,   delta_alppha = 2.00e-02,   Tmax =   1767.9 K
# n =  35,     u =    621.0 cm/s,     K =   1719.7 1/s,     Tmax =   1762.7 K,     elaped time: 00 02:20:02
# Flame extinguished at n =  36. Restoring n =  35 with alpha = 8.00e+00 and delta_alpha = 4.00e-04 (E2)
# n =  37,     u =    621.0 cm/s,     K =   1719.6 1/s,     Tmax =   1762.7 K,     elaped time: 00 02:21:04
# Flame (almost) extinguished at n = 37. Abortion criterion satisfied.
#
# **** ... done. Rxn 017  'H2O(8) + M <=> H(4) + OH(6) + M' has a normalized SA coefficient of  -4.18e-73 ****
#
#
# Conducting SA for rxn 18 out of 73: 2 H2O(8) <=> H(4) + H2O(8) + OH(6)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.3 1/s,     Tmax =   1788.5 K,     elaped time: 00 02:21:16
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.6 1/s,     Tmax =   1772.8 K,     elaped time: 00 02:22:51
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.8 K
# n =  34,     u =    620.3 cm/s,     K =   1717.9 1/s,     Tmax =   1762.6 K,     elaped time: 00 02:25:18
# Flame extinguished at n =  35. Restoring n =  34 with alpha = 9.56e+00 and delta_alpha = 4.00e-04 (E2)
# n =  36,     u =    620.3 cm/s,     K =   1717.7 1/s,     Tmax =   1762.5 K,     elaped time: 00 02:26:20
# Flame (almost) extinguished at n = 36. Abortion criterion satisfied.
#
# **** ... done. Rxn 018  '2 H2O(8) <=> H(4) + H2O(8) + OH(6)' has a normalized SA coefficient of  -5.00e-74 ****
#
#
# Conducting SA for rxn 19 out of 73: H(4) + HO2(10) <=> H2O(8) + O(5)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.6 K,     elaped time: 00 02:26:32
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.7 1/s,     Tmax =   1773.2 K,     elaped time: 00 02:28:06
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.2 K
# n =  30,     u =    617.7 cm/s,     K =   1711.7 1/s,     Tmax =   1770.1 K,     elaped time: 00 02:29:01
# Error: Did not converge at n =  31. alpha = 9.56e+00,   delta_alppha = 2.00e-02,   Tmax =   1768.9 K
# n =  35,     u =    621.0 cm/s,     K =   1719.7 1/s,     Tmax =   1760.5 K,     elaped time: 00 02:32:25
# Flame extinguished at n =  36. Restoring n =  35 with alpha = 8.00e+00 and delta_alpha = 4.00e-04 (E2)
# n =  37,     u =    621.0 cm/s,     K =   1719.3 1/s,     Tmax =   1760.4 K,     elaped time: 00 02:33:18
# Flame (almost) extinguished at n = 37. Abortion criterion satisfied.
#
# **** ... done. Rxn 019  'H(4) + HO2(10) <=> H2O(8) + O(5)' has a normalized SA coefficient of  -4.58e-02 ****
#
#
# Conducting SA for rxn 20 out of 73: HO2(10) + OH(6) <=> H2O(8) + O2(2)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.3 1/s,     Tmax =   1788.4 K,     elaped time: 00 02:33:30
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.6 1/s,     Tmax =   1772.7 K,     elaped time: 00 02:35:05
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.7 K
# n =  29,     u =    617.1 cm/s,     K =   1710.0 1/s,     Tmax =   1770.6 K,     elaped time: 00 02:36:07
# Error: Did not converge at n =  30. alpha = 9.54e+00,   delta_alppha = 2.00e-02,   Tmax =   1769.5 K
# n =  31,     u =    618.4 cm/s,     K =   1713.3 1/s,     Tmax =   1746.5 K,     elaped time: 00 02:38:16
# Error: Did not converge at n =  32. alpha = 9.58e+00,   delta_alppha = 2.00e-02,   Tmax =   1768.1 K
# n =  35,     u =    621.0 cm/s,     K =   1719.8 1/s,     Tmax =   1763.1 K,     elaped time: 00 02:41:00
# Flame extinguished at n =  36. Restoring n =  35 with alpha = 8.00e+00 and delta_alpha = 4.00e-04 (E2)
# n =  37,     u =    621.0 cm/s,     K =   1719.6 1/s,     Tmax =   1763.0 K,     elaped time: 00 02:42:16
# Flame (almost) extinguished at n = 37. Abortion criterion satisfied.
#
# **** ... done. Rxn 020  'HO2(10) + OH(6) <=> H2O(8) + O2(2)' has a normalized SA coefficient of   2.68e-03 ****
#
#
# Conducting SA for rxn 21 out of 73: CH4(1) + OH(6) <=> CH3(18) + H2O(8)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.2 1/s,     Tmax =   1787.5 K,     elaped time: 00 02:42:29
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  26,     u =    615.1 cm/s,     K =   1704.7 1/s,     Tmax =   1772.2 K,     elaped time: 00 02:44:06
# Error: Did not converge at n =  27. alpha = 9.48e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.2 K
# n =  28,     u =    616.4 cm/s,     K =   1708.1 1/s,     Tmax =   1770.1 K,     elaped time: 00 02:44:55
# Error: Did not converge at n =  29. alpha = 9.52e+00,   delta_alppha = 2.00e-02,   Tmax =   1768.9 K
# n =  30,     u =    617.7 cm/s,     K =   1711.4 1/s,     Tmax =   1768.6 K,     elaped time: 00 02:47:04
# Error: Did not converge at n =  31. alpha = 9.56e+00,   delta_alppha = 2.00e-02,   Tmax =   1767.4 K
# n =  34,     u =    620.3 cm/s,     K =   1717.9 1/s,     Tmax =   1762.1 K,     elaped time: 00 02:49:35
# Flame extinguished at n =  35. Restoring n =  34 with alpha = 9.56e+00 and delta_alpha = 4.00e-04 (E2)
# n =  36,     u =    620.3 cm/s,     K =   1717.7 1/s,     Tmax =   1762.0 K,     elaped time: 00 02:50:44
# Flame (almost) extinguished at n = 36. Abortion criterion satisfied.
#
# **** ... done. Rxn 021  'CH4(1) + OH(6) <=> CH3(18) + H2O(8)' has a normalized SA coefficient of  -2.13e-06 ****
#
#
# Conducting SA for rxn 22 out of 73: CH3(18) + O(5) <=> CH2O(19) + H(4)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.3 1/s,     Tmax =   1787.8 K,     elaped time: 00 02:50:56
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  26,     u =    615.1 cm/s,     K =   1704.8 1/s,     Tmax =   1772.6 K,     elaped time: 00 02:52:28
# Error: Did not converge at n =  27. alpha = 9.48e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.6 K
# n =  33,     u =    619.7 cm/s,     K =   1716.1 1/s,     Tmax =   1762.3 K,     elaped time: 00 02:54:48
# Flame extinguished at n =  34. Restoring n =  33 with alpha = 9.56e+00 and delta_alpha = 4.00e-04 (E2)
# n =  35,     u =    619.7 cm/s,     K =   1715.8 1/s,     Tmax =   1762.2 K,     elaped time: 00 02:55:40
# Flame (almost) extinguished at n = 35. Abortion criterion satisfied.
#
# **** ... done. Rxn 022  'CH3(18) + O(5) <=> CH2O(19) + H(4)' has a normalized SA coefficient of  -8.53e-02 ****
#
#
# Conducting SA for rxn 23 out of 73: CH3(18) + OH(6) <=> CH2O(19) + H2(7)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.5 K,     elaped time: 00 02:55:52
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.7 1/s,     Tmax =   1773.2 K,     elaped time: 00 02:57:27
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.2 K
# n =  28,     u =    616.4 cm/s,     K =   1708.4 1/s,     Tmax =   1772.2 K,     elaped time: 00 02:57:59
# Error: Did not converge at n =  29. alpha = 9.52e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.2 K
# n =  30,     u =    617.7 cm/s,     K =   1711.8 1/s,     Tmax =   1770.1 K,     elaped time: 00 02:58:54
# Error: Did not converge at n =  31. alpha = 9.56e+00,   delta_alppha = 2.00e-02,   Tmax =   1768.9 K
# n =  32,     u =    619.0 cm/s,     K =   1715.0 1/s,     Tmax =   1768.6 K,     elaped time: 00 03:01:02
# Error: Did not converge at n =  33. alpha = 9.60e+00,   delta_alppha = 2.00e-02,   Tmax =   1767.3 K
# n =  36,     u =    621.7 cm/s,     K =   1721.9 1/s,     Tmax =   1761.1 K,     elaped time: 00 03:03:41
# Flame extinguished at n =  37. Restoring n =  36 with alpha = 9.00e+00 and delta_alpha = 4.00e-04 (E2)
# n =  38,     u =    621.8 cm/s,     K =   1721.5 1/s,     Tmax =   1761.1 K,     elaped time: 00 03:04:35
# Flame (almost) extinguished at n = 38. Abortion criterion satisfied.
#
# **** ... done. Rxn 023  'CH3(18) + OH(6) <=> CH2O(19) + H2(7)' has a normalized SA coefficient of   1.17e-03 ****
#
#
# Conducting SA for rxn 24 out of 73: CH3(18) + O2(2) <=> CH2O(19) + OH(6)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.8 K,     elaped time: 00 03:04:47
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  28,     u =    616.4 cm/s,     K =   1708.4 1/s,     Tmax =   1772.6 K,     elaped time: 00 03:06:28
# Error: Did not converge at n =  29. alpha = 9.52e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.6 K
# n =  32,     u =    619.0 cm/s,     K =   1715.1 1/s,     Tmax =   1746.3 K,     elaped time: 00 03:07:49
# Error: Did not converge at n =  33. alpha = 9.60e+00,   delta_alppha = 2.00e-02,   Tmax =   1768.0 K
# n =  36,     u =    621.7 cm/s,     K =   1722.0 1/s,     Tmax =   1762.6 K,     elaped time: 00 03:10:58
# Flame extinguished at n =  37. Restoring n =  36 with alpha = 9.00e+00 and delta_alpha = 4.00e-04 (E2)
# n =  38,     u =    621.8 cm/s,     K =   1721.8 1/s,     Tmax =   1762.5 K,     elaped time: 00 03:12:14
# Flame (almost) extinguished at n = 38. Abortion criterion satisfied.
#
# **** ... done. Rxn 024  'CH3(18) + O2(2) <=> CH2O(19) + OH(6)' has a normalized SA coefficient of  -6.22e-12 ****
#
#
# Conducting SA for rxn 25 out of 73: CH3(18) + HO2(10) <=> CH3O(26) + OH(6)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.6 1/s,     Tmax =   1789.9 K,     elaped time: 00 03:12:26
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  31,     u =    618.4 cm/s,     K =   1713.9 1/s,     Tmax =   1772.1 K,     elaped time: 00 03:14:16
# Error: Did not converge at n =  32. alpha = 9.58e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.0 K
# n =  32,     u =    619.0 cm/s,     K =   1715.6 1/s,     Tmax =   1771.0 K,     elaped time: 00 03:14:52
# Error: Did not converge at n =  33. alpha = 9.60e+00,   delta_alppha = 2.00e-02,   Tmax =   1769.9 K
# n =  33,     u =    619.7 cm/s,     K =   1717.2 1/s,     Tmax =   1769.9 K,     elaped time: 00 03:15:31
# Error: Did not converge at n =  34. alpha = 9.58e+00,   delta_alppha = 2.00e-02,   Tmax =   1769.6 K
# n =  39,     u =    623.8 cm/s,     K =   1727.5 1/s,     Tmax =   1760.0 K,     elaped time: 00 03:18:21
# Flame extinguished at n =  40. Restoring n =  39 with alpha = 9.04e+00 and delta_alpha = 4.00e-04 (E2)
# n =  41,     u =    623.8 cm/s,     K =   1727.0 1/s,     Tmax =   1759.9 K,     elaped time: 00 03:19:16
# Flame (almost) extinguished at n = 41. Abortion criterion satisfied.
#
# **** ... done. Rxn 025  'CH3(18) + HO2(10) <=> CH3O(26) + OH(6)' has a normalized SA coefficient of  -4.12e-03 ****
#
#
# Conducting SA for rxn 26 out of 73: CH3(18) + O2(2) <=> CH3O(26) + O(5)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.6 K,     elaped time: 00 03:19:28
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  28,     u =    616.4 cm/s,     K =   1708.4 1/s,     Tmax =   1772.4 K,     elaped time: 00 03:21:26
# Error: Did not converge at n =  29. alpha = 9.52e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.3 K
# n =  30,     u =    617.7 cm/s,     K =   1711.8 1/s,     Tmax =   1770.3 K,     elaped time: 00 03:22:09
# Error: Did not converge at n =  31. alpha = 9.56e+00,   delta_alppha = 2.00e-02,   Tmax =   1769.1 K
# n =  32,     u =    619.0 cm/s,     K =   1715.1 1/s,     Tmax =   1746.7 K,     elaped time: 00 03:24:12
# Error: Did not converge at n =  33. alpha = 9.60e+00,   delta_alppha = 2.00e-02,   Tmax =   1767.7 K
# n =  36,     u =    621.7 cm/s,     K =   1721.9 1/s,     Tmax =   1761.8 K,     elaped time: 00 03:28:01
# Flame extinguished at n =  37. Restoring n =  36 with alpha = 9.00e+00 and delta_alpha = 4.00e-04 (E2)
# n =  38,     u =    621.8 cm/s,     K =   1721.6 1/s,     Tmax =   1761.7 K,     elaped time: 00 03:28:58
# Flame (almost) extinguished at n = 38. Abortion criterion satisfied.
#
# **** ... done. Rxn 026  'CH3(18) + O2(2) <=> CH3O(26) + O(5)' has a normalized SA coefficient of  -6.76e-21 ****
#
#
# Conducting SA for rxn 27 out of 73: CH3O(26) (+M) <=> CH2O(19) + H(4) (+M)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.2 K,     elaped time: 00 03:29:10
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.7 1/s,     Tmax =   1772.4 K,     elaped time: 00 03:30:47
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.4 K
# n =  29,     u =    617.1 cm/s,     K =   1710.1 1/s,     Tmax =   1770.3 K,     elaped time: 00 03:31:32
# Error: Did not converge at n =  30. alpha = 9.54e+00,   delta_alppha = 2.00e-02,   Tmax =   1769.1 K
# n =  34,     u =    620.3 cm/s,     K =   1718.1 1/s,     Tmax =   1761.8 K,     elaped time: 00 03:35:41
# Flame extinguished at n =  35. Restoring n =  34 with alpha = 9.56e+00 and delta_alpha = 4.00e-04 (E2)
# n =  36,     u =    620.3 cm/s,     K =   1717.8 1/s,     Tmax =   1761.8 K,     elaped time: 00 03:36:46
# Flame (almost) extinguished at n = 36. Abortion criterion satisfied.
#
# **** ... done. Rxn 027  'CH3O(26) (+M) <=> CH2O(19) + H(4) (+M)' has a normalized SA coefficient of  -1.34e-15 ****
#
#
# Conducting SA for rxn 28 out of 73: CH3O(26) + H(4) <=> CH2O(19) + H2(7)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.6 K,     elaped time: 00 03:36:58
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.7 1/s,     Tmax =   1773.1 K,     elaped time: 00 03:38:35
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.2 K
# n =  28,     u =    616.4 cm/s,     K =   1708.3 1/s,     Tmax =   1772.2 K,     elaped time: 00 03:39:07
# Error: Did not converge at n =  29. alpha = 9.52e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.1 K
# n =  30,     u =    617.7 cm/s,     K =   1711.7 1/s,     Tmax =   1770.0 K,     elaped time: 00 03:39:46
# Error: Did not converge at n =  31. alpha = 9.56e+00,   delta_alppha = 2.00e-02,   Tmax =   1768.8 K
# n =  35,     u =    621.0 cm/s,     K =   1719.6 1/s,     Tmax =   1759.9 K,     elaped time: 00 03:43:10
# Flame extinguished at n =  36. Restoring n =  35 with alpha = 8.00e+00 and delta_alpha = 4.00e-04 (E2)
# n =  37,     u =    621.0 cm/s,     K =   1719.2 1/s,     Tmax =   1759.7 K,     elaped time: 00 03:44:28
# Flame (almost) extinguished at n = 37. Abortion criterion satisfied.
#
# **** ... done. Rxn 028  'CH3O(26) + H(4) <=> CH2O(19) + H2(7)' has a normalized SA coefficient of  -1.67e-03 ****
#
#
# Conducting SA for rxn 29 out of 73: CH3O(26) + H(4) <=> CH3(18) + OH(6)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.5 K,     elaped time: 00 03:44:40
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.7 1/s,     Tmax =   1773.0 K,     elaped time: 00 03:46:13
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.1 K
# n =  28,     u =    616.4 cm/s,     K =   1708.3 1/s,     Tmax =   1772.1 K,     elaped time: 00 03:46:45
# Error: Did not converge at n =  29. alpha = 9.52e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.0 K
# n =  30,     u =    617.7 cm/s,     K =   1711.7 1/s,     Tmax =   1769.9 K,     elaped time: 00 03:47:31
# Error: Did not converge at n =  31. alpha = 9.56e+00,   delta_alppha = 2.00e-02,   Tmax =   1768.6 K
# n =  34,     u =    620.3 cm/s,     K =   1718.1 1/s,     Tmax =   1763.5 K,     elaped time: 00 03:50:36
# Flame extinguished at n =  35. Restoring n =  34 with alpha = 9.56e+00 and delta_alpha = 4.00e-04 (E2)
# n =  36,     u =    620.3 cm/s,     K =   1717.8 1/s,     Tmax =   1763.5 K,     elaped time: 00 03:52:21
# Flame (almost) extinguished at n = 36. Abortion criterion satisfied.
#
# **** ... done. Rxn 029  'CH3O(26) + H(4) <=> CH3(18) + OH(6)' has a normalized SA coefficient of   8.49e-03 ****
#
#
# Conducting SA for rxn 30 out of 73: CH3O(26) + O(5) <=> CH2O(19) + OH(6)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.6 K,     elaped time: 00 03:52:33
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.7 1/s,     Tmax =   1773.2 K,     elaped time: 00 03:54:08
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.2 K
# n =  30,     u =    617.7 cm/s,     K =   1711.7 1/s,     Tmax =   1770.1 K,     elaped time: 00 03:55:01
# Error: Did not converge at n =  31. alpha = 9.56e+00,   delta_alppha = 2.00e-02,   Tmax =   1768.9 K
# n =  35,     u =    621.0 cm/s,     K =   1719.7 1/s,     Tmax =   1760.5 K,     elaped time: 00 03:58:17
# Flame extinguished at n =  36. Restoring n =  35 with alpha = 8.00e+00 and delta_alpha = 4.00e-04 (E2)
# n =  37,     u =    621.0 cm/s,     K =   1719.3 1/s,     Tmax =   1760.4 K,     elaped time: 00 03:59:20
# Flame (almost) extinguished at n = 37. Abortion criterion satisfied.
#
# **** ... done. Rxn 030  'CH3O(26) + O(5) <=> CH2O(19) + OH(6)' has a normalized SA coefficient of  -4.58e-02 ****
#
#
# Conducting SA for rxn 31 out of 73: CH3O(26) + OH(6) <=> CH2O(19) + H2O(8)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.6 K,     elaped time: 00 03:59:32
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.7 1/s,     Tmax =   1773.2 K,     elaped time: 00 04:01:09
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.2 K
# n =  28,     u =    616.4 cm/s,     K =   1708.3 1/s,     Tmax =   1772.2 K,     elaped time: 00 04:01:41
# Error: Did not converge at n =  29. alpha = 9.52e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.2 K
# n =  30,     u =    617.7 cm/s,     K =   1711.7 1/s,     Tmax =   1770.1 K,     elaped time: 00 04:02:20
# Error: Did not converge at n =  31. alpha = 9.56e+00,   delta_alppha = 2.00e-02,   Tmax =   1768.9 K
# n =  35,     u =    621.0 cm/s,     K =   1719.6 1/s,     Tmax =   1760.3 K,     elaped time: 00 04:05:54
# Flame extinguished at n =  36. Restoring n =  35 with alpha = 8.00e+00 and delta_alpha = 4.00e-04 (E2)
# n =  37,     u =    621.0 cm/s,     K =   1719.2 1/s,     Tmax =   1760.1 K,     elaped time: 00 04:06:54
# Flame (almost) extinguished at n = 37. Abortion criterion satisfied.
#
# **** ... done. Rxn 031  'CH3O(26) + OH(6) <=> CH2O(19) + H2O(8)' has a normalized SA coefficient of  -4.63e-02 ****
#
#
# Conducting SA for rxn 32 out of 73: CH3O(26) + O2(2) <=> CH2O(19) + HO2(10)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.6 K,     elaped time: 00 04:07:06
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.7 1/s,     Tmax =   1773.3 K,     elaped time: 00 04:08:42
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.3 K
# n =  28,     u =    616.4 cm/s,     K =   1708.4 1/s,     Tmax =   1772.3 K,     elaped time: 00 04:09:14
# Error: Did not converge at n =  29. alpha = 9.52e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.3 K
# n =  30,     u =    617.7 cm/s,     K =   1711.8 1/s,     Tmax =   1770.2 K,     elaped time: 00 04:10:03
# Error: Did not converge at n =  31. alpha = 9.56e+00,   delta_alppha = 2.00e-02,   Tmax =   1769.0 K
# n =  32,     u =    619.0 cm/s,     K =   1715.0 1/s,     Tmax =   1768.7 K,     elaped time: 00 04:12:13
# Error: Did not converge at n =  33. alpha = 9.60e+00,   delta_alppha = 2.00e-02,   Tmax =   1767.4 K
# n =  36,     u =    621.7 cm/s,     K =   1721.9 1/s,     Tmax =   1761.2 K,     elaped time: 00 04:15:02
# Flame extinguished at n =  37. Restoring n =  36 with alpha = 9.00e+00 and delta_alpha = 4.00e-04 (E2)
# n =  38,     u =    621.8 cm/s,     K =   1721.5 1/s,     Tmax =   1761.1 K,     elaped time: 00 04:15:58
# Flame (almost) extinguished at n = 38. Abortion criterion satisfied.
#
# **** ... done. Rxn 032  'CH3O(26) + O2(2) <=> CH2O(19) + HO2(10)' has a normalized SA coefficient of  -2.49e-05 ****
#
#
# Conducting SA for rxn 33 out of 73: CH3(18) + CH3O(26) <=> CH2O(19) + CH4(1)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.5 K,     elaped time: 00 04:16:10
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.6 1/s,     Tmax =   1773.0 K,     elaped time: 00 04:17:47
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.0 K
# n =  28,     u =    616.4 cm/s,     K =   1708.3 1/s,     Tmax =   1772.0 K,     elaped time: 00 04:18:20
# Error: Did not converge at n =  29. alpha = 9.52e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.0 K
# n =  34,     u =    620.3 cm/s,     K =   1718.1 1/s,     Tmax =   1763.4 K,     elaped time: 00 04:21:26
# Flame extinguished at n =  35. Restoring n =  34 with alpha = 9.56e+00 and delta_alpha = 4.00e-04 (E2)
# n =  36,     u =    620.3 cm/s,     K =   1717.8 1/s,     Tmax =   1763.4 K,     elaped time: 00 04:22:54
# Flame (almost) extinguished at n = 36. Abortion criterion satisfied.
#
# **** ... done. Rxn 033  'CH3(18) + CH3O(26) <=> CH2O(19) + CH4(1)' has a normalized SA coefficient of  -6.22e-02 ****
#
#
# Conducting SA for rxn 34 out of 73: CH3(18) + O2(2) <=> CH3O(26) + O(5)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.6 K,     elaped time: 00 04:23:06
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.7 1/s,     Tmax =   1773.3 K,     elaped time: 00 04:24:43
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.3 K
# n =  28,     u =    616.4 cm/s,     K =   1708.4 1/s,     Tmax =   1772.3 K,     elaped time: 00 04:25:15
# Error: Did not converge at n =  29. alpha = 9.52e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.3 K
# n =  32,     u =    619.0 cm/s,     K =   1711.6 1/s,     Tmax =   1768.8 K,     elaped time: 00 04:26:29
# Error: Did not converge at n =  33. alpha = 9.60e+00,   delta_alppha = 2.00e-02,   Tmax =   1767.6 K
# n =  36,     u =    621.7 cm/s,     K =   1721.9 1/s,     Tmax =   1761.7 K,     elaped time: 00 04:30:08
# Flame extinguished at n =  37. Restoring n =  36 with alpha = 9.00e+00 and delta_alpha = 4.00e-04 (E2)
# n =  38,     u =    621.8 cm/s,     K =   1721.6 1/s,     Tmax =   1761.6 K,     elaped time: 00 04:31:07
# Flame (almost) extinguished at n = 38. Abortion criterion satisfied.
#
# **** ... done. Rxn 034  'CH3(18) + O2(2) <=> CH3O(26) + O(5)' has a normalized SA coefficient of  -2.20e-21 ****
#
#
# Conducting SA for rxn 35 out of 73: CH3(18) + O(5) <=> CH3O(26)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.5 K,     elaped time: 00 04:31:19
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.7 1/s,     Tmax =   1773.1 K,     elaped time: 00 04:32:56
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.1 K
# n =  30,     u =    617.7 cm/s,     K =   1711.7 1/s,     Tmax =   1769.9 K,     elaped time: 00 04:33:50
# Error: Did not converge at n =  31. alpha = 9.56e+00,   delta_alppha = 2.00e-02,   Tmax =   1768.7 K
# n =  34,     u =    620.3 cm/s,     K =   1718.1 1/s,     Tmax =   1763.6 K,     elaped time: 00 04:36:50
# Flame extinguished at n =  35. Restoring n =  34 with alpha = 9.56e+00 and delta_alpha = 4.00e-04 (E2)
# n =  36,     u =    620.3 cm/s,     K =   1717.8 1/s,     Tmax =   1763.6 K,     elaped time: 00 04:39:46
# Flame (almost) extinguished at n = 36. Abortion criterion satisfied.
#
# **** ... done. Rxn 035  'CH3(18) + O(5) <=> CH3O(26)' has a normalized SA coefficient of  -6.66e-05 ****
#
#
# Conducting SA for rxn 36 out of 73: CH3(18) + HO2(10) <=> CH3O(26) + OH(6)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.6 1/s,     Tmax =   1789.9 K,     elaped time: 00 04:39:58
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  31,     u =    618.4 cm/s,     K =   1713.9 1/s,     Tmax =   1772.2 K,     elaped time: 00 04:41:48
# Error: Did not converge at n =  32. alpha = 9.58e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.2 K
# n =  33,     u =    619.7 cm/s,     K =   1717.2 1/s,     Tmax =   1770.1 K,     elaped time: 00 04:42:44
# Error: Did not converge at n =  34. alpha = 9.58e+00,   delta_alppha = 2.00e-02,   Tmax =   1768.9 K
# n =  37,     u =    622.4 cm/s,     K =   1724.0 1/s,     Tmax =   1763.4 K,     elaped time: 00 04:46:21
# Flame extinguished at n =  38. Restoring n =  37 with alpha = 1.00e+01 and delta_alpha = 4.00e-04 (E2)
# n =  39,     u =    622.5 cm/s,     K =   1723.8 1/s,     Tmax =   1763.3 K,     elaped time: 00 04:48:27
# Flame (almost) extinguished at n = 39. Abortion criterion satisfied.
#
# **** ... done. Rxn 036  'CH3(18) + HO2(10) <=> CH3O(26) + OH(6)' has a normalized SA coefficient of   1.05e-03 ****
#
#
# ...
#
# **** ... done. Rxn 061  'CH3(18) + OH(6) <=> CH2(17) + H2O(8)' has a normalized SA coefficient of   1.25e-08 ****
#
#
# Conducting SA for rxn 62 out of 73: CH2(17) + CH4(1) <=> 2 CH3(18)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.6 K,     elaped time: 00 08:00:47
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.7 1/s,     Tmax =   1773.2 K,     elaped time: 00 08:02:22
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.2 K
# n =  30,     u =    617.7 cm/s,     K =   1711.7 1/s,     Tmax =   1770.1 K,     elaped time: 00 08:03:20
# Error: Did not converge at n =  31. alpha = 9.56e+00,   delta_alppha = 2.00e-02,   Tmax =   1768.9 K
# n =  35,     u =    621.0 cm/s,     K =   1719.7 1/s,     Tmax =   1760.5 K,     elaped time: 00 08:06:24
# Flame extinguished at n =  36. Restoring n =  35 with alpha = 8.00e+00 and delta_alpha = 4.00e-04 (E2)
# n =  37,     u =    621.0 cm/s,     K =   1719.2 1/s,     Tmax =   1760.3 K,     elaped time: 00 08:07:23
# Flame (almost) extinguished at n = 37. Abortion criterion satisfied.
#
# **** ... done. Rxn 062  'CH2(17) + CH4(1) <=> 2 CH3(18)' has a normalized SA coefficient of  -6.37e-10 ****
#
#
# Conducting SA for rxn 63 out of 73: CH2(17) + HO2(10) <=> CH3(18) + O2(2)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.6 K,     elaped time: 00 08:07:35
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.7 1/s,     Tmax =   1773.2 K,     elaped time: 00 08:09:10
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.2 K
# n =  30,     u =    617.7 cm/s,     K =   1711.7 1/s,     Tmax =   1770.1 K,     elaped time: 00 08:10:01
# Error: Did not converge at n =  31. alpha = 9.56e+00,   delta_alppha = 2.00e-02,   Tmax =   1768.9 K
# n =  35,     u =    621.0 cm/s,     K =   1719.7 1/s,     Tmax =   1760.6 K,     elaped time: 00 08:13:17
# Flame extinguished at n =  36. Restoring n =  35 with alpha = 8.00e+00 and delta_alpha = 4.00e-04 (E2)
# n =  37,     u =    621.0 cm/s,     K =   1719.3 1/s,     Tmax =   1760.4 K,     elaped time: 00 08:14:15
# Flame (almost) extinguished at n = 37. Abortion criterion satisfied.
#
# **** ... done. Rxn 063  'CH2(17) + HO2(10) <=> CH3(18) + O2(2)' has a normalized SA coefficient of  -2.86e-07 ****
#
#
# Conducting SA for rxn 64 out of 73: CH2(17) + OH(6) <=> CH3(18) + O(5)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.7 1/s,     Tmax =   1790.8 K,     elaped time: 00 08:14:27
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  33,     u =    619.7 cm/s,     K =   1717.5 1/s,     Tmax =   1772.0 K,     elaped time: 00 08:16:25
# Error: Did not converge at n =  34. alpha = 9.58e+00,   delta_alppha = 2.00e-02,   Tmax =   1770.9 K
# n =  34,     u =    620.3 cm/s,     K =   1719.2 1/s,     Tmax =   1770.9 K,     elaped time: 00 08:17:00
# Error: Did not converge at n =  35. alpha = 9.58e+00,   delta_alppha = 2.00e-02,   Tmax =   1769.8 K
# n =  39,     u =    623.8 cm/s,     K =   1727.7 1/s,     Tmax =   1762.3 K,     elaped time: 00 08:19:50
# Flame extinguished at n =  40. Restoring n =  39 with alpha = 9.04e+00 and delta_alpha = 4.00e-04 (E2)
# n =  41,     u =    623.8 cm/s,     K =   1727.4 1/s,     Tmax =   1762.3 K,     elaped time: 00 08:20:56
# Flame (almost) extinguished at n = 41. Abortion criterion satisfied.
#
# **** ... done. Rxn 064  'CH2(17) + OH(6) <=> CH3(18) + O(5)' has a normalized SA coefficient of   2.13e-03 ****
#
#
# Conducting SA for rxn 65 out of 73: CH2(17) + CH3O(26) <=> CH2O(19) + CH3(18)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.6 K,     elaped time: 00 08:21:07
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.7 1/s,     Tmax =   1773.2 K,     elaped time: 00 08:22:42
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.2 K
# n =  30,     u =    617.7 cm/s,     K =   1711.7 1/s,     Tmax =   1770.1 K,     elaped time: 00 08:23:35
# Error: Did not converge at n =  31. alpha = 9.56e+00,   delta_alppha = 2.00e-02,   Tmax =   1768.9 K
# n =  35,     u =    621.0 cm/s,     K =   1719.7 1/s,     Tmax =   1760.5 K,     elaped time: 00 08:27:16
# Flame extinguished at n =  36. Restoring n =  35 with alpha = 8.00e+00 and delta_alpha = 4.00e-04 (E2)
# n =  37,     u =    621.0 cm/s,     K =   1719.3 1/s,     Tmax =   1760.4 K,     elaped time: 00 08:28:20
# Flame (almost) extinguished at n = 37. Abortion criterion satisfied.
#
# **** ... done. Rxn 065  'CH2(17) + CH3O(26) <=> CH2O(19) + CH3(18)' has a normalized SA coefficient of  -4.58e-02 ****
#
#
# Conducting SA for rxn 66 out of 73: CO(12) + O(5) (+M) <=> CO2(13) (+M)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.6 K,     elaped time: 00 08:28:32
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.7 1/s,     Tmax =   1773.2 K,     elaped time: 00 08:30:06
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.2 K
# n =  28,     u =    616.4 cm/s,     K =   1708.3 1/s,     Tmax =   1772.2 K,     elaped time: 00 08:30:38
# Error: Did not converge at n =  29. alpha = 9.52e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.2 K
# n =  30,     u =    617.7 cm/s,     K =   1711.7 1/s,     Tmax =   1770.1 K,     elaped time: 00 08:31:17
# Error: Did not converge at n =  31. alpha = 9.56e+00,   delta_alppha = 2.00e-02,   Tmax =   1768.9 K
# n =  35,     u =    621.0 cm/s,     K =   1719.6 1/s,     Tmax =   1760.4 K,     elaped time: 00 08:35:21
# Flame extinguished at n =  36. Restoring n =  35 with alpha = 8.00e+00 and delta_alpha = 4.00e-04 (E2)
# n =  37,     u =    621.0 cm/s,     K =   1719.2 1/s,     Tmax =   1760.2 K,     elaped time: 00 08:36:23
# Flame (almost) extinguished at n = 37. Abortion criterion satisfied.
#
# **** ... done. Rxn 066  'CO(12) + O(5) (+M) <=> CO2(13) (+M)' has a normalized SA coefficient of  -1.02e-04 ****
#
#
# Conducting SA for rxn 67 out of 73: CO(12) + O2(2) <=> CO2(13) + O(5)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.6 K,     elaped time: 00 08:36:35
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.7 1/s,     Tmax =   1773.2 K,     elaped time: 00 08:38:10
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.2 K
# n =  30,     u =    617.7 cm/s,     K =   1711.7 1/s,     Tmax =   1770.1 K,     elaped time: 00 08:39:08
# Error: Did not converge at n =  31. alpha = 9.56e+00,   delta_alppha = 2.00e-02,   Tmax =   1768.9 K
# n =  35,     u =    621.0 cm/s,     K =   1719.7 1/s,     Tmax =   1760.6 K,     elaped time: 00 08:42:27
# Flame extinguished at n =  36. Restoring n =  35 with alpha = 8.00e+00 and delta_alpha = 4.00e-04 (E2)
# n =  37,     u =    621.0 cm/s,     K =   1719.3 1/s,     Tmax =   1760.4 K,     elaped time: 00 08:43:25
# Flame (almost) extinguished at n = 37. Abortion criterion satisfied.
#
# **** ... done. Rxn 067  'CO(12) + O2(2) <=> CO2(13) + O(5)' has a normalized SA coefficient of  -3.24e-32 ****
#
#
# Conducting SA for rxn 68 out of 73: CO(12) + OH(6) <=> CO2(13) + H(4)
#
# n =   2,     u =    600.0 cm/s,     K =   1668.3 1/s,     Tmax =   1790.9 K,     elaped time: 00 08:43:37
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  51,     u =    632.0 cm/s,     K =   1750.8 1/s,     Tmax =   1763.8 K,     elaped time: 00 08:48:00
# Flame extinguished at n =  52. Restoring n =  51 with alpha = 9.28e+00 and delta_alpha = 4.00e-04 (E2)
# n =  53,     u =    632.0 cm/s,     K =   1750.4 1/s,     Tmax =   1763.7 K,     elaped time: 00 08:49:17
# Flame (almost) extinguished at n = 53. Abortion criterion satisfied.
#
# **** ... done. Rxn 068  'CO(12) + OH(6) <=> CO2(13) + H(4)' has a normalized SA coefficient of   6.79e-04 ****
#
#
# Conducting SA for rxn 69 out of 73: CO(12) + HO2(10) <=> CO2(13) + OH(6)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.6 K,     elaped time: 00 08:49:30
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.7 1/s,     Tmax =   1773.2 K,     elaped time: 00 08:51:05
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.2 K
# n =  30,     u =    617.7 cm/s,     K =   1711.8 1/s,     Tmax =   1770.1 K,     elaped time: 00 08:52:02
# Error: Did not converge at n =  31. alpha = 9.56e+00,   delta_alppha = 2.00e-02,   Tmax =   1768.9 K
# n =  35,     u =    621.0 cm/s,     K =   1719.7 1/s,     Tmax =   1760.6 K,     elaped time: 00 08:55:53
# Flame extinguished at n =  36. Restoring n =  35 with alpha = 8.00e+00 and delta_alpha = 4.00e-04 (E2)
# n =  37,     u =    621.0 cm/s,     K =   1719.3 1/s,     Tmax =   1760.4 K,     elaped time: 00 08:56:52
# Flame (almost) extinguished at n = 37. Abortion criterion satisfied.
#
# **** ... done. Rxn 069  'CO(12) + HO2(10) <=> CO2(13) + OH(6)' has a normalized SA coefficient of  -6.58e-16 ****
#
#
# Conducting SA for rxn 70 out of 73: HCO(14) + O(5) <=> CO2(13) + H(4)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.6 K,     elaped time: 00 08:57:04
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.7 1/s,     Tmax =   1773.2 K,     elaped time: 00 08:58:38
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.2 K
# n =  28,     u =    616.4 cm/s,     K =   1708.3 1/s,     Tmax =   1772.2 K,     elaped time: 00 08:59:10
# Error: Did not converge at n =  29. alpha = 9.52e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.2 K
# n =  30,     u =    617.7 cm/s,     K =   1711.7 1/s,     Tmax =   1770.0 K,     elaped time: 00 08:59:51
# Error: Did not converge at n =  31. alpha = 9.56e+00,   delta_alppha = 2.00e-02,   Tmax =   1768.8 K
# n =  35,     u =    621.0 cm/s,     K =   1719.6 1/s,     Tmax =   1759.3 K,     elaped time: 00 09:03:50
# Flame extinguished at n =  36. Restoring n =  35 with alpha = 8.00e+00 and delta_alpha = 4.00e-04 (E2)
#
# Flame extinguished at n =  37. Restoring n =  35 with alpha = 8.00e+00 and delta_alpha = 8.00e-06 (E2)
#
# Error: Did not converge at n =  38. alpha = 8.00e+00,   delta_alppha = 8.00e-06,   Tmax =   1759.3 K
# n =  38,     u =    621.0 cm/s,     K =   1719.0 1/s,     Tmax =   1759.3 K,     elaped time: 00 09:08:48
# Flame (almost) extinguished at n = 38. Abortion criterion satisfied.
#
# **** ... done. Rxn 070  'HCO(14) + O(5) <=> CO2(13) + H(4)' has a normalized SA coefficient of  -4.83e-02 ****
#
#
# Conducting SA for rxn 71 out of 73: CH2(17) + O2(2) <=> CO2(13) + 2 H(4)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.5 1/s,     Tmax =   1789.4 K,     elaped time: 00 09:08:59
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  29,     u =    617.1 cm/s,     K =   1710.3 1/s,     Tmax =   1772.9 K,     elaped time: 00 09:10:38
# Error: Did not converge at n =  30. alpha = 9.54e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.0 K
# n =  30,     u =    617.7 cm/s,     K =   1712.0 1/s,     Tmax =   1772.0 K,     elaped time: 00 09:11:10
# Error: Did not converge at n =  31. alpha = 9.56e+00,   delta_alppha = 2.00e-02,   Tmax =   1770.9 K
# n =  32,     u =    619.0 cm/s,     K =   1715.4 1/s,     Tmax =   1769.8 K,     elaped time: 00 09:11:51
# Error: Did not converge at n =  33. alpha = 9.60e+00,   delta_alppha = 2.00e-02,   Tmax =   1768.6 K
# n =  38,     u =    623.1 cm/s,     K =   1725.4 1/s,     Tmax =   1759.8 K,     elaped time: 00 09:15:32
# Flame extinguished at n =  39. Restoring n =  38 with alpha = 9.02e+00 and delta_alpha = 4.00e-04 (E2)
# n =  40,     u =    623.1 cm/s,     K =   1725.0 1/s,     Tmax =   1759.7 K,     elaped time: 00 09:16:29
# Flame (almost) extinguished at n = 40. Abortion criterion satisfied.
#
# **** ... done. Rxn 071  'CH2(17) + O2(2) <=> CO2(13) + 2 H(4)' has a normalized SA coefficient of   3.30e-04 ****
#
#
# Conducting SA for rxn 72 out of 73: CH2(17) + O2(2) <=> CO2(13) + H2(7)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.3 1/s,     Tmax =   1788.5 K,     elaped time: 00 09:16:41
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.6 1/s,     Tmax =   1772.9 K,     elaped time: 00 09:18:15
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1771.9 K
# n =  28,     u =    616.4 cm/s,     K =   1708.3 1/s,     Tmax =   1771.9 K,     elaped time: 00 09:18:47
# Error: Did not converge at n =  29. alpha = 9.52e+00,   delta_alppha = 2.00e-02,   Tmax =   1770.8 K
# n =  30,     u =    617.7 cm/s,     K =   1711.6 1/s,     Tmax =   1745.7 K,     elaped time: 00 09:19:34
# Error: Did not converge at n =  31. alpha = 9.56e+00,   delta_alppha = 2.00e-02,   Tmax =   1769.5 K
# n =  31,     u =    618.4 cm/s,     K =   1709.8 1/s,     Tmax =   1769.5 K,     elaped time: 00 09:20:10
# Error: Did not converge at n =  32. alpha = 9.58e+00,   delta_alppha = 2.00e-02,   Tmax =   1768.2 K
# n =  35,     u =    621.0 cm/s,     K =   1719.8 1/s,     Tmax =   1763.2 K,     elaped time: 00 09:23:47
# Flame extinguished at n =  36. Restoring n =  35 with alpha = 8.00e+00 and delta_alpha = 4.00e-04 (E2)
# n =  37,     u =    621.0 cm/s,     K =   1719.6 1/s,     Tmax =   1763.2 K,     elaped time: 00 09:25:03
# Flame (almost) extinguished at n = 37. Abortion criterion satisfied.
#
# **** ... done. Rxn 072  'CH2(17) + O2(2) <=> CO2(13) + H2(7)' has a normalized SA coefficient of  -6.42e-04 ****
#
#
# Conducting SA for rxn 73 out of 73: CH3O(26) + CO(12) <=> CH3(18) + CO2(13)
#
# n =   2,     u =    600.0 cm/s,     K =   1667.4 1/s,     Tmax =   1788.6 K,     elaped time: 00 09:25:15
# Flame extinguished at n =   3. Restoring n =   2 with alpha = 9.00e+00 and delta_alpha = 2.00e-02 (E2)
# n =  27,     u =    615.8 cm/s,     K =   1706.7 1/s,     Tmax =   1773.2 K,     elaped time: 00 09:26:49
# Error: Did not converge at n =  28. alpha = 9.50e+00,   delta_alppha = 2.00e-02,   Tmax =   1772.2 K
# n =  30,     u =    617.7 cm/s,     K =   1711.7 1/s,     Tmax =   1770.1 K,     elaped time: 00 09:27:47
# Error: Did not converge at n =  31. alpha = 9.56e+00,   delta_alppha = 2.00e-02,   Tmax =   1768.9 K
# n =  35,     u =    621.0 cm/s,     K =   1719.7 1/s,     Tmax =   1760.5 K,     elaped time: 00 09:31:45
# Flame extinguished at n =  36. Restoring n =  35 with alpha = 8.00e+00 and delta_alpha = 4.00e-04 (E2)
# n =  37,     u =    621.0 cm/s,     K =   1719.2 1/s,     Tmax =   1760.3 K,     elaped time: 00 09:32:37
# Flame (almost) extinguished at n = 37. Abortion criterion satisfied.
#
# **** ... done. Rxn 073  'CH3O(26) + CO(12) <=> CH3(18) + CO2(13)' has a normalized SA coefficient of  -4.92e-10 ****
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-82f472664f7c> in <module>()
#      47     d, h = divmod(h, 24)
#      48
# ---> 49     SA_sorted, rxns_sorted = extractTopSA(logFile,SA,rxnList,d,h,m,s)
#      50
#      51 # plot topSA + legend
#
# <ipython-input-5-c76278252de8> in extractTopSA(logFile, SA, rxnList, d, h, m, s)
#     473     num1 = np.linspace(0,len(SA)-1,len(SA))
#     474     num1 = zip(SA,num1)
# --> 475     num1.sort(key=lambda x: abs(x[0]), reverse=True)
#     476     SA_sorted = []
#     477     rxns_sorted = []
#
# AttributeError: 'zip' object has no attribute 'sort'

# %%
SA_sorted, rxns_sorted = extractTopSA(logFile,SA,rxnList,d,h,m,s)
# Out:
#  Sorted Top SA coefficients:
# 000   -1.48e-01,  HCO(14) + OH(6) <=> CO(12) + H2O(8)
# 001   -1.06e-01,  H(4) + HCO(14) <=> CO(12) + H2(7)
# 002   -8.76e-02,  CH2(17) + OH(6) <=> CH2O(19) + H(4)
# 003   -8.53e-02,  CH3(18) + O(5) <=> CH2O(19) + H(4)
# 004    7.10e-02,  CH3(18) + O(5) <=> CO(12) + H(4) + H2(7)
# 005   -6.29e-02,  HCO(14) + O(5) <=> CO(12) + OH(6)
# 006   -6.22e-02,  CH3(18) + CH3O(26) <=> CH2O(19) + CH4(1)
# 007   -6.22e-02,  CH3(18) + HCO(14) <=> CH4(1) + CO(12)
# 008   -4.83e-02,  HCO(14) + O(5) <=> CO2(13) + H(4)
# 009   -4.63e-02,  CH3O(26) + OH(6) <=> CH2O(19) + H2O(8)
#
#
# Total elapsed time with SA: 00 days and 09:32:37

# %% [markdown]
# # Main – run a case study

# %%
# improve troubleshooting

case = [[0.5,'nphi=0.32',0.32,'CH4(1):0.2353, O2(2):21, N2(3):79'],
       [1,'nphi=0.33',0.33,'CH4(1):0.2463, O2(2):21, N2(3):79'],
       [2,'nphi=0.34',0.34,'CH4(1):0.2576, O2(2):21, N2(3):79'],
       [3,'nphi=0.35',0.35,'CH4(1):0.2692, O2(2):21, N2(3):79'],
       [5,'nphi=0.36',0.36,'CH4(1):0.2813, O2(2):21, N2(3):79'],
       [10,'nphi=0.37',0.37,'CH4(1):0.2937, O2(2):21, N2(3):79'],
       [15,'nphi=0.38',0.38,'CH4(1):0.3065, O2(2):21, N2(3):79'],
       [30,'nphi=0.39',0.39,'CH4(1):0.3197, O2(2):21, N2(3):79'],
       [50,'nphi=0.40',0.40,'CH4(1):0.3333, O2(2):21, N2(3):79'],
       [70,'nphi=0.41',0.41,'CH4(1):0.3475, O2(2):21, N2(3):79'],
       [100,'nphi=0.42',0.42,'CH4(1):0.3621, O2(2):21, N2(3):79'],
       [110,'nphi=0.43',0.43,'CH4(1):0.3772, O2(2):21, N2(3):79'],
       [120,'nphi=0.44',0.44,'CH4(1):0.3929, O2(2):21, N2(3):79'],
       [140,'nphi=0.45',0.45,'CH4(1):0.4091, O2(2):21, N2(3):79'],
       [160,'nphi=0.46',0.46,'CH4(1):0.4259, O2(2):21, N2(3):79'],
       [180,'nphi=0.47',0.47,'CH4(1):0.4434, O2(2):21, N2(3):79'],
       [190,'nphi=0.48',0.48,'CH4(1):0.4615, O2(2):21, N2(3):79'],
       [195,'nphi=0.49',0.49,'CH4(1):0.4804, O2(2):21, N2(3):79'],
       [200,'nphi=0.50',0.50,'CH4(1):0.5000, O2(2):21, N2(3):79'],
       [150,'nphi=0.51',0.51,'CH4(1):0.5204, O2(2):21, N2(3):79'],
       [130,'nphi=0.52',0.52,'CH4(1):0.5417, O2(2):21, N2(3):79'],
       [100,'nphi=0.53',0.53,'CH4(1):0.5638, O2(2):21, N2(3):79'],
       [80,'nphi=0.54',0.54,'CH4(1):0.5870, O2(2):21, N2(3):79'],
       [40,'nphi=0.55',0.55,'CH4(1):0.6111, O2(2):21, N2(3):79'],
       [20,'nphi=0.56',0.56,'CH4(1):0.6364, O2(2):21, N2(3):79'],
       [15,'nphi=0.57',0.57,'CH4(1):0.6628, O2(2):21, N2(3):79'],
       [10,'nphi=0.58',0.58,'CH4(1):0.6905, O2(2):21, N2(3):79'],
       [7,'nphi=0.59',0.59,'CH4(1):0.7195, O2(2):21, N2(3):79'],
       [4,'nphi=0.60',0.60,'CH4(1):0.7500, O2(2):21, N2(3):79'],
       [2,'nphi=0.61',0.61,'CH4(1):0.7821, O2(2):21, N2(3):79'],
       [1,'nphi=0.62',0.62,'CH4(1):0.8158, O2(2):21, N2(3):79'],
       [0.5,'nphi=0.63',0.63,'CH4(1):0.8514, O2(2):21, N2(3):79']]


nphi = []
Kfinal = []

for icase in case:
    
    print("\n")
    print(icase[0])
    print(icase[1])
    print(icase[2])
    print("\n")
    
    
    initialAxialVelocity = icase[0]
    name = icase[1]
    nphi.append(icase[2])
    composition = icase[3]

    t0 = time.time()   # set timer
    # initialize parameters from user input
    gas, oppFlame, alpha, delta_alpha, width = initializer(initialAxialVelocity)

    KPrime,K_tot,strainRatePoint,log,T_max,n_last_burning,alpha,delta_alpha,grid_pnts,SAalpha,SAd_alpha,u0 = solver(
        gas, oppFlame, alpha, delta_alpha, width, t0)

    kfinal.append(K)
    
    Sc = computeConsumptionSpeed(oppFlame)

    t1 = time.time() - t0
    m, s = divmod(t1, 60)
    h, m = divmod(m, 60)
    if verboseLevel >= 1:
        printResults(KPrime, oppFlame, gas.density, Sc, h, m, s)

    logFile = writePrimeToFile(h, m, s, KPrime, oppFlame, Sc, alpha, delta_alpha, grid_pnts,log)
    plotFigs(oppFlame,strainRatePoint,K_tot,T_max,u0,logFile,n_last_burning)  
    
print("Done.")
# Out:
# 1
# nphi=0.40
# 0.4
#
#
# Solving xo1247-C2i with u0 =    1.0 cm/s:
#
# Flame extinguished at n =   0. Restoring n =   0 with alpha = 1.00e+00 and delta_alpha = 2.00e-02 (E2)
#
# Couldn't ignite. Changing initialAxialVelocity from    1.0 to    0.5 at n=0 (TrSh2)
#
# Flame extinguished at n =   1. Restoring n =   0 with alpha = 1.00e+00 and delta_alpha = 2.00e-02 (E2)
#
# Couldn't ignite. Changing initialAxialVelocity from    0.5 to    0.3 at n=0 (TrSh2)
#
# Flame extinguished at n =   1. Restoring n =   0 with alpha = 1.00e+00 and delta_alpha = 2.00e-02 (E2)
#
# Couldn't ignite. Changing initialAxialVelocity from    0.3 to    0.3 at n=0 (TrSh2)
#
# Flame extinguished at n =   1. Restoring n =   0 with alpha = 1.00e+00 and delta_alpha = 2.00e-02 (E2)
#
# Couldn't ignite. Changing initialAxialVelocity from    0.3 to    0.3 at n=0 (TrSh2)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-8e36dbe93f28> in <module>()
#      41
#      42     KPrime,K_tot,strainRatePoint,log,T_max,n_last_burning,alpha,delta_alpha,grid_pnts,SAalpha,SAd_alpha,u0 = solver(
# ---> 43         gas, oppFlame, alpha, delta_alpha, width, t0)
#      44
#      45     kfinal.append(K)
#
# <ipython-input-3-c76278252de8> in solver(gas, oppFlame, alpha, delta_alpha, width, t0)
#      71         # try solving
#      72         try:
# ---> 73             oppFlame.solve(loglevel=0, refine_grid=refine, auto=True)
#      74         except Exception as e:
#      75             if verboseLevel >= 2:
#
# interfaces\cython\cantera\onedim.pyx in cantera._cantera.Sim1D.solve (interfaces\cython\cantera\_cantera.cpp:81762)()
#
# interfaces\cython\cantera\func1.pyx in cantera._cantera.func_callback (interfaces\cython\cantera\_cantera.cpp:6083)()
#
# D:\Anaconda\envs\canteraEnv\lib\site-packages\cantera\interrupts.py in no_op(t)
# ----> 1 def no_op(t):
#       2     """
#       3     This function does nothing. It is used as an interrupt in the 1D solver
#       4     C++ loop where a pure Python function is needed in order for
#       5     KeyboardInterrupt events to be captured.
#
# KeyboardInterrupt:

# %% [markdown]
# ## INSTRUCTIONS
# Convert your mechanism into a .cti format using the <a href="http://www.cantera.org/docs/sphinx/html/cti/input-files.html#sec-ck-format-conversion">ck2cti</a> script.<BR>
# Then, run this ESR solver for your case, and try to get it to converge at a minimum time without SA, mainly by optimizing the axial velocity<BR> (by setting topSA to 0).<BR>
# Once no auto-troubleshooting messages appear (i.e., "Couldn't ignite. Changing initialAxialVelocity..."; note that the "Flame extinguished at n = x. Restoring n = y" messages should always always appear), start with the sensitivity study by setting topSA to the desired value.
#
#
# ### SOME GENERAL ALGORITHM COMMENTS:
#
# The velocity is multiplied each iteration by a `strain factor`:<BR>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$v = v \times strain Factor$<BR>
# $\alpha$ is an auxilary parameter defined as:<BR>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$\alpha_{i+1} = \alpha_i + \Delta\alpha$<BR>
# initialized with the following default values<BR>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$\alpha_0 = 1$, and $\Delta\alpha = 1$<BR>
# and results in the following series:<BR>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$\alpha = [1, 2, 3, 4...]$<BR>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$strain Factor = [2, 3/2, 4/3...]$,<BR>
# since the `strain factor` is redefined each iteration as:<BR>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$strain Factor = \alpha_i / \alpha _{i-1}$<BR>
# Once extinction occurs, however, the last burning solution is restored and $\Delta\alpha$ now gets divided by $\Delta\alpha Factor$ with a default value of 50:<BR>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$\Delta\alpha = \Delta\alpha / 50$<BR>
# causing the $\alpha$ and `strain factor` series to advance in smaller steps:<BR>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$\alpha = [1, 2, 3, 4, 4.02, 4.04, 4.06...]$<BR>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$strain Factor = [2, 3/2, 4/3, 4.02/4, 4.04/4.02, 4.06/4.04...]$<BR>
# So if $\Delta\alpha Factor$ = 50, $\Delta\alpha$ will get the following values: 1, 2E-2, 4E-4, 8E-6, 1.6E-7, etc...<BR>
# Convergence creteria are both $\Delta T < \Delta T _{min}$ and $\Delta\alpha < \Delta\alpha_{min}$<BR>
#
#
# ### CRITERIA FOR GRID REFINEMENT:
#
# ratio: &nbsp;additional points will be added if the ratio of the spacing on<BR>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;either side of a grid point exceeds this value<BR>
# slope: Adds points in regions of high slope.<BR>
# curve: Adds points in regions of high curvature.<BR>
# prune: if the slope or curve criteria are satisfied to the level of<BR>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;'prune', the grid point is assumed not to be needed and is removed.<BR>
#
#
# ## Installing the latest version of Cantera:
#
# Open CMD and type:<BR>
# `Conda create –n canteraEnv python=3 jupyter`<BR>
# `activate canteraEnv`<BR>
# `conda install -c https://conda.anaconda.org/cantera/label/dev cantera`<BR>
# `python -m ipykernel install --user --name canteraEnv --display-name "Cantera-Py3"`<BR>
#
# Make sure you activate the above environment each time you want to install relevant dependencies.
